# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import KFold
from sklearn.metrics import accuracy_score,r2_score
import xgboost as xgb
from matplotlib import pyplot as plt
from hyperopt import hp

# %%
data_dir = "F:/TARGET frontier/TXT33/"
data_name = "train"
tail = "fe1"
train_data = pd.DataFrame()
for i in range(2015,2019):
    res = pd.read_csv(data_dir+data_name+str(i)+tail+".csv",encoding="shift-jis",dtype={'レースID(旧)':str})
    train_data = pd.concat([train_data,res])

# %%
pd.set_option('display.max_columns', 100)
train_data.head()
# Out:
#    場所  芝・ダ    距離  クラス名  馬場状態  騎手コード  枠番  性別  年齢  キャリア    斤量   間隔  休み明け〜戦目  \
# 0   1    1  1200     0     2   5212   6   2   3    13  56.0  6.0      5.0
# 1   1    1  1200     0     2   5339   6   1   3    10  54.0  3.0      3.0
# 2   1    1  1200     0     2   5203   3   2   3     9  56.0  5.0      2.0
# 3   1    1  1200     0     2   1150   4   1   5    17  55.0  2.0      4.0
# 4   1    1  1200     0     2   1004   8   1   3    15  54.0  2.0      4.0
#
#    種牡馬  父タイプ名  調教師コード  前走場所  前芝・ダ     前距離  前クラス名  前走馬場状態  前走騎手コード  前走枠番  前走脚質  \
# 0  364      8    1105    13     2  1400.0      2       2    660.0   2.0     3
# 1  281      8    1002     1     2  1200.0      4       3   5339.0   7.0     3
# 2  387      5    1089     3     2  1200.0      2       3   1018.0   8.0     2
# 3   56      1    1134     2     2  1200.0      2       2   1150.0   6.0     2
# 4  193      4    1030     2     2  1200.0      2       2   1134.0   2.0     5
#
#    前走斤量  前走Ave-3F  前走上り3F  前走PCI3  前走RPCI  前PCI  前好走  前走平均1Fタイム  前走着差タイム  \
# 0  54.0      37.2    33.9   59.53    58.2  59.7    0      11.93      0.2
# 1  54.0      34.5    34.6   48.80    46.9  49.7    0      11.52      0.0
# 2  56.0      34.5    34.4   50.13    48.0  50.3    0      11.48      0.4
# 3  53.0      34.1    34.4   48.17    46.3  49.1    0      11.42      0.0
# 4  53.0      33.6    36.4   48.17    46.3  42.3    1      11.67      1.5
#
#    前走単勝オッズ   着差    レースID(旧)  複勝オッズ下限  複勝オッズ上限   複勝配当  単勝オッズ
# 0     14.6  0.0  0615581112      1.9      2.7  190.0    5.4
# 1      2.2  0.0  0615581111      1.3      1.6  130.0    2.8
# 2     28.6  0.2  0615581106      1.8      2.5  180.0    6.2
# 3     19.1  0.3  0615581108      1.7      2.5    0.0    6.6
# 4      8.6  0.3  0615581116      6.3      9.7    0.0   33.9

# %%
#test_data
test_data = pd.read_csv(data_dir+"predict2019"+tail+".csv",encoding="shift-jis",dtype={'レースID(旧)':str})
test_x = test_data.drop(["着差","レースID(旧)","複勝オッズ下限","複勝オッズ上限","複勝配当"],axis=1)
test_y = test_data["着差"]

# %%
train_x = train_data.drop(["着差","レースID(旧)","複勝オッズ下限","複勝オッズ上限","複勝配当"],axis=1)
train_y = train_data["着差"]

# %%
#xgboostのparams
params = {
    'booster':'gbtree',
    'objective':'reg:squarederror',
    'eta':0.005,
    'gamma':0.0,
    'alpha':0.0,
    'lambda':1.0,
    'min_child_weight':1,
    'max_depth':7,
    'subsample':0.8,
    'colsample_bytree':0.8,
    'random_state':71,
}

# %%
#これがないとエラー履くので注意
train_y.fillna(1,inplace=True)
test_y.fillna(1,inplace=True)

# %%
scores = []
histories = []
models = []
kf = KFold(n_splits=4,shuffle=False)
for tr_idx,va_idx in kf.split(train_x):
    tr_x, va_x = train_x.iloc[tr_idx], train_x.iloc[va_idx]
    tr_y, va_y = train_y.iloc[tr_idx], train_y.iloc[va_idx]
    dtrain = xgb.DMatrix(tr_x,label=tr_y)
    dvalid = xgb.DMatrix(va_x,label=va_y)
    watchlist = [(dtrain,"train"),(dvalid,"eval")]
    evals_result = {}
    model = xgb.train(
        params,
        dtrain,
        num_boost_round=10000,
        early_stopping_rounds=50,
        evals=watchlist,
        evals_result=evals_result,
        verbose_eval=50
    )
    models.append(model)
    histories.append(evals_result)
    va_pred = model.predict(dvalid)
    va_y.fillna(0.5,inplace=True) #ここまでok
    #print(va_pred[:10])
    #print(va_y[:10])
    score = r2_score(va_y,va_pred)
    scores.append(score)

print(*scores)
print(np.mean(scores))
# Out:
# C:\Anaconda3\lib\site-packages\xgboost\core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# [0]	train-rmse:1.69028	eval-rmse:1.68537
# Multiple eval metrics have been passed: 'eval-rmse' will be used for early stopping.
#
# Will train until eval-rmse hasn't improved in 50 rounds.
# [50]	train-rmse:1.5263	eval-rmse:1.54402
# [100]	train-rmse:1.41242	eval-rmse:1.4499
# [150]	train-rmse:1.33261	eval-rmse:1.38743
# [200]	train-rmse:1.27751	eval-rmse:1.34698
# [250]	train-rmse:1.23835	eval-rmse:1.32039
# [300]	train-rmse:1.21059	eval-rmse:1.30321
# [350]	train-rmse:1.18983	eval-rmse:1.2918
# [400]	train-rmse:1.17408	eval-rmse:1.28407
# [450]	train-rmse:1.16147	eval-rmse:1.27871
# [500]	train-rmse:1.1513	eval-rmse:1.27487
# [550]	train-rmse:1.14288	eval-rmse:1.272
# [600]	train-rmse:1.13563	eval-rmse:1.26987
# [650]	train-rmse:1.12942	eval-rmse:1.26815
# [700]	train-rmse:1.12384	eval-rmse:1.26685
# [750]	train-rmse:1.1186	eval-rmse:1.2657
# [800]	train-rmse:1.11338	eval-rmse:1.26481
# [850]	train-rmse:1.1086	eval-rmse:1.26409
# [900]	train-rmse:1.10448	eval-rmse:1.26333
# [950]	train-rmse:1.10073	eval-rmse:1.26283
# [1000]	train-rmse:1.09703	eval-rmse:1.26229
# [1050]	train-rmse:1.09336	eval-rmse:1.26182
# [1100]	train-rmse:1.08991	eval-rmse:1.26143
# [1150]	train-rmse:1.08665	eval-rmse:1.26116
# [1200]	train-rmse:1.08352	eval-rmse:1.26091
# [1250]	train-rmse:1.0805	eval-rmse:1.26064
# [1300]	train-rmse:1.07776	eval-rmse:1.26044
# [1350]	train-rmse:1.075	eval-rmse:1.26025
# [1400]	train-rmse:1.07232	eval-rmse:1.26003
# [1450]	train-rmse:1.06959	eval-rmse:1.25978
# [1500]	train-rmse:1.06693	eval-rmse:1.25966
# [1550]	train-rmse:1.06445	eval-rmse:1.25948
# [1600]	train-rmse:1.06172	eval-rmse:1.25937
# [1650]	train-rmse:1.05917	eval-rmse:1.25919
# [1700]	train-rmse:1.05682	eval-rmse:1.25903
# [1750]	train-rmse:1.05441	eval-rmse:1.25887
# [1800]	train-rmse:1.05199	eval-rmse:1.25878
# [1850]	train-rmse:1.04952	eval-rmse:1.25865
# [1900]	train-rmse:1.04735	eval-rmse:1.25855
# [1950]	train-rmse:1.04504	eval-rmse:1.25839
# [2000]	train-rmse:1.04275	eval-rmse:1.25831
# [2050]	train-rmse:1.04059	eval-rmse:1.25828
# [2100]	train-rmse:1.0384	eval-rmse:1.25821
# [2150]	train-rmse:1.03637	eval-rmse:1.25816
# [2200]	train-rmse:1.03414	eval-rmse:1.25807
# [2250]	train-rmse:1.03198	eval-rmse:1.25803
# [2300]	train-rmse:1.02997	eval-rmse:1.25795
# [2350]	train-rmse:1.02773	eval-rmse:1.25793
# [2400]	train-rmse:1.02586	eval-rmse:1.25791
# [2450]	train-rmse:1.02384	eval-rmse:1.25786
# [2500]	train-rmse:1.0219	eval-rmse:1.25778
# [2550]	train-rmse:1.01988	eval-rmse:1.25774
# [2600]	train-rmse:1.0178	eval-rmse:1.25768
# [2650]	train-rmse:1.01589	eval-rmse:1.25765
# [2700]	train-rmse:1.01421	eval-rmse:1.25759
# [2750]	train-rmse:1.0124	eval-rmse:1.25756
# Stopping. Best iteration:
# [2724]	train-rmse:1.01329	eval-rmse:1.25754
# C:\Anaconda3\lib\site-packages\xgboost\core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# [0]	train-rmse:1.69321	eval-rmse:1.67642
# Multiple eval metrics have been passed: 'eval-rmse' will be used for early stopping.
#
# Will train until eval-rmse hasn't improved in 50 rounds.
# [50]	train-rmse:1.53264	eval-rmse:1.52555
# [100]	train-rmse:1.41984	eval-rmse:1.42351
# [150]	train-rmse:1.34032	eval-rmse:1.35461
# [200]	train-rmse:1.28403	eval-rmse:1.30899
# [250]	train-rmse:1.24374	eval-rmse:1.27869
# [300]	train-rmse:1.21449	eval-rmse:1.25842
# [350]	train-rmse:1.19294	eval-rmse:1.24485
# [400]	train-rmse:1.17596	eval-rmse:1.23501
# [450]	train-rmse:1.16281	eval-rmse:1.2281
# [500]	train-rmse:1.15226	eval-rmse:1.22354
# [550]	train-rmse:1.14313	eval-rmse:1.22002
# [600]	train-rmse:1.13549	eval-rmse:1.21735
# [650]	train-rmse:1.1289	eval-rmse:1.21511
# [700]	train-rmse:1.12278	eval-rmse:1.21334
# [750]	train-rmse:1.11686	eval-rmse:1.21187
# [800]	train-rmse:1.11157	eval-rmse:1.21068
# [850]	train-rmse:1.10702	eval-rmse:1.20969
# [900]	train-rmse:1.10252	eval-rmse:1.20894
# [950]	train-rmse:1.09814	eval-rmse:1.2083
# [1000]	train-rmse:1.09405	eval-rmse:1.20769
# [1050]	train-rmse:1.09029	eval-rmse:1.20703
# [1100]	train-rmse:1.08689	eval-rmse:1.20652
# [1150]	train-rmse:1.08362	eval-rmse:1.20602
# [1200]	train-rmse:1.08054	eval-rmse:1.20559
# [1250]	train-rmse:1.07765	eval-rmse:1.20513
# [1300]	train-rmse:1.07448	eval-rmse:1.20474
# [1350]	train-rmse:1.07148	eval-rmse:1.20431
# [1400]	train-rmse:1.06868	eval-rmse:1.20397
# [1450]	train-rmse:1.066	eval-rmse:1.20366
# [1500]	train-rmse:1.06341	eval-rmse:1.2034
# [1550]	train-rmse:1.0607	eval-rmse:1.2032
# [1600]	train-rmse:1.0579	eval-rmse:1.20297
# [1650]	train-rmse:1.05544	eval-rmse:1.2027
# [1700]	train-rmse:1.05285	eval-rmse:1.20248
# [1750]	train-rmse:1.05054	eval-rmse:1.20224
# [1800]	train-rmse:1.0482	eval-rmse:1.20207
# [1850]	train-rmse:1.04581	eval-rmse:1.20186
# [1900]	train-rmse:1.04348	eval-rmse:1.20167
# [1950]	train-rmse:1.04108	eval-rmse:1.2015
# [2000]	train-rmse:1.03903	eval-rmse:1.20137
# [2050]	train-rmse:1.03681	eval-rmse:1.2012
# [2100]	train-rmse:1.03464	eval-rmse:1.20107
# [2150]	train-rmse:1.03274	eval-rmse:1.20094
# [2200]	train-rmse:1.03065	eval-rmse:1.20081
# [2250]	train-rmse:1.02843	eval-rmse:1.20073
# [2300]	train-rmse:1.02648	eval-rmse:1.20064
# [2350]	train-rmse:1.02455	eval-rmse:1.20051
# [2400]	train-rmse:1.02253	eval-rmse:1.20039
# [2450]	train-rmse:1.02047	eval-rmse:1.20022
# [2500]	train-rmse:1.01823	eval-rmse:1.20005
# [2550]	train-rmse:1.01637	eval-rmse:1.20002
# [2600]	train-rmse:1.01452	eval-rmse:1.19992
# [2650]	train-rmse:1.01277	eval-rmse:1.19987
# [2700]	train-rmse:1.01072	eval-rmse:1.19983
# [2750]	train-rmse:1.0089	eval-rmse:1.1998
# [2800]	train-rmse:1.00704	eval-rmse:1.19966
# [2850]	train-rmse:1.00521	eval-rmse:1.19959
# [2900]	train-rmse:1.00335	eval-rmse:1.19954
# [2950]	train-rmse:1.00148	eval-rmse:1.19947
# [3000]	train-rmse:0.999599	eval-rmse:1.19936
# [3050]	train-rmse:0.997838	eval-rmse:1.19935
# Stopping. Best iteration:
# [3023]	train-rmse:0.99872	eval-rmse:1.19933
# C:\Anaconda3\lib\site-packages\xgboost\core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# [0]	train-rmse:1.71192	eval-rmse:1.61837
# Multiple eval metrics have been passed: 'eval-rmse' will be used for early stopping.
#
# Will train until eval-rmse hasn't improved in 50 rounds.
# [50]	train-rmse:1.55267	eval-rmse:1.46073
# [100]	train-rmse:1.44057	eval-rmse:1.35384
# [150]	train-rmse:1.36125	eval-rmse:1.28148
# [200]	train-rmse:1.30466	eval-rmse:1.234
# [250]	train-rmse:1.26384	eval-rmse:1.20305
# [300]	train-rmse:1.23438	eval-rmse:1.18239
# [350]	train-rmse:1.21246	eval-rmse:1.1686
# [400]	train-rmse:1.19475	eval-rmse:1.15906
# [450]	train-rmse:1.18101	eval-rmse:1.15254
# [500]	train-rmse:1.16995	eval-rmse:1.14792
# [550]	train-rmse:1.16067	eval-rmse:1.14428
# [600]	train-rmse:1.15263	eval-rmse:1.14182
# [650]	train-rmse:1.14591	eval-rmse:1.14005
# [700]	train-rmse:1.14001	eval-rmse:1.1384
# [750]	train-rmse:1.13386	eval-rmse:1.13706
# [800]	train-rmse:1.12847	eval-rmse:1.13593
# [850]	train-rmse:1.12362	eval-rmse:1.13499
# [900]	train-rmse:1.1186	eval-rmse:1.13424
# [950]	train-rmse:1.11441	eval-rmse:1.13355
# [1000]	train-rmse:1.1098	eval-rmse:1.13297
# [1050]	train-rmse:1.10583	eval-rmse:1.1325
# [1100]	train-rmse:1.10217	eval-rmse:1.13203
# [1150]	train-rmse:1.09836	eval-rmse:1.13163
# [1200]	train-rmse:1.09477	eval-rmse:1.13123
# [1250]	train-rmse:1.09129	eval-rmse:1.13085
# [1300]	train-rmse:1.08801	eval-rmse:1.13051
# [1350]	train-rmse:1.08459	eval-rmse:1.1302
# [1400]	train-rmse:1.08127	eval-rmse:1.12993
# [1450]	train-rmse:1.07877	eval-rmse:1.12966
# [1500]	train-rmse:1.07591	eval-rmse:1.12946
# [1550]	train-rmse:1.07296	eval-rmse:1.12917
# [1600]	train-rmse:1.06987	eval-rmse:1.12897
# [1650]	train-rmse:1.06719	eval-rmse:1.12877
# [1700]	train-rmse:1.06453	eval-rmse:1.12858
# [1750]	train-rmse:1.06193	eval-rmse:1.12842
# [1800]	train-rmse:1.0593	eval-rmse:1.12824
# [1850]	train-rmse:1.05689	eval-rmse:1.12806
# [1900]	train-rmse:1.05428	eval-rmse:1.12796
# [1950]	train-rmse:1.05192	eval-rmse:1.12782
# [2000]	train-rmse:1.04965	eval-rmse:1.12769
# [2050]	train-rmse:1.04702	eval-rmse:1.12756
# [2100]	train-rmse:1.04474	eval-rmse:1.12746
# [2150]	train-rmse:1.04249	eval-rmse:1.12733
# [2200]	train-rmse:1.04039	eval-rmse:1.12727
# [2250]	train-rmse:1.03828	eval-rmse:1.12717
# [2300]	train-rmse:1.03605	eval-rmse:1.12714
# [2350]	train-rmse:1.03374	eval-rmse:1.12712
# [2400]	train-rmse:1.03144	eval-rmse:1.12703
# [2450]	train-rmse:1.02945	eval-rmse:1.12701
# [2500]	train-rmse:1.02738	eval-rmse:1.1269
# [2550]	train-rmse:1.02532	eval-rmse:1.12682
# [2600]	train-rmse:1.02331	eval-rmse:1.12676
# [2650]	train-rmse:1.02113	eval-rmse:1.12669
# [2700]	train-rmse:1.01923	eval-rmse:1.12665
# [2750]	train-rmse:1.01724	eval-rmse:1.12657
# [2800]	train-rmse:1.0153	eval-rmse:1.12656
# [2850]	train-rmse:1.01332	eval-rmse:1.12654
# [2900]	train-rmse:1.01132	eval-rmse:1.12649
# [2950]	train-rmse:1.00941	eval-rmse:1.12642
# [3000]	train-rmse:1.0074	eval-rmse:1.1264
# [3050]	train-rmse:1.00529	eval-rmse:1.12636
# [3100]	train-rmse:1.00337	eval-rmse:1.12642
# Stopping. Best iteration:
# [3051]	train-rmse:1.00525	eval-rmse:1.12636
# C:\Anaconda3\lib\site-packages\xgboost\core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# [0]	train-rmse:1.66017	eval-rmse:1.77288
# Multiple eval metrics have been passed: 'eval-rmse' will be used for early stopping.
#
# Will train until eval-rmse hasn't improved in 50 rounds.
# [50]	train-rmse:1.50493	eval-rmse:1.61975
# [100]	train-rmse:1.39576	eval-rmse:1.51484
# [150]	train-rmse:1.31888	eval-rmse:1.44294
# [200]	train-rmse:1.26465	eval-rmse:1.39456
# [250]	train-rmse:1.22599	eval-rmse:1.36182
# [300]	train-rmse:1.19797	eval-rmse:1.33968
# [350]	train-rmse:1.17752	eval-rmse:1.32441
# [400]	train-rmse:1.1611	eval-rmse:1.31357
# [450]	train-rmse:1.14826	eval-rmse:1.30578
# [500]	train-rmse:1.13791	eval-rmse:1.30038
# [550]	train-rmse:1.12892	eval-rmse:1.29605
# [600]	train-rmse:1.1211	eval-rmse:1.29295
# [650]	train-rmse:1.1145	eval-rmse:1.29034
# [700]	train-rmse:1.10812	eval-rmse:1.28819
# [750]	train-rmse:1.10238	eval-rmse:1.28645
# [800]	train-rmse:1.0969	eval-rmse:1.28501
# [850]	train-rmse:1.09215	eval-rmse:1.28387
# [900]	train-rmse:1.08734	eval-rmse:1.28289
# [950]	train-rmse:1.08289	eval-rmse:1.28185
# [1000]	train-rmse:1.07842	eval-rmse:1.28109
# [1050]	train-rmse:1.07432	eval-rmse:1.28042
# [1100]	train-rmse:1.07065	eval-rmse:1.27982
# [1150]	train-rmse:1.06667	eval-rmse:1.27934
# [1200]	train-rmse:1.063	eval-rmse:1.27891
# [1250]	train-rmse:1.05976	eval-rmse:1.2786
# [1300]	train-rmse:1.05639	eval-rmse:1.27832
# [1350]	train-rmse:1.05325	eval-rmse:1.27804
# [1400]	train-rmse:1.0501	eval-rmse:1.2778
# [1450]	train-rmse:1.04721	eval-rmse:1.27748
# [1500]	train-rmse:1.04434	eval-rmse:1.27725
# [1550]	train-rmse:1.04154	eval-rmse:1.27709
# [1600]	train-rmse:1.03915	eval-rmse:1.27689
# [1650]	train-rmse:1.0364	eval-rmse:1.2766
# [1700]	train-rmse:1.03403	eval-rmse:1.27641
# [1750]	train-rmse:1.03149	eval-rmse:1.27624
# [1800]	train-rmse:1.02896	eval-rmse:1.27608
# [1850]	train-rmse:1.02662	eval-rmse:1.27597
# [1900]	train-rmse:1.02423	eval-rmse:1.27581
# [1950]	train-rmse:1.02211	eval-rmse:1.27559
# [2000]	train-rmse:1.01982	eval-rmse:1.27547
# [2050]	train-rmse:1.01762	eval-rmse:1.27537
# [2100]	train-rmse:1.01548	eval-rmse:1.27522
# [2150]	train-rmse:1.01341	eval-rmse:1.27513
# [2200]	train-rmse:1.01138	eval-rmse:1.27497
# [2250]	train-rmse:1.00919	eval-rmse:1.27484
# [2300]	train-rmse:1.00706	eval-rmse:1.27472
# [2350]	train-rmse:1.00505	eval-rmse:1.27459
# [2400]	train-rmse:1.00293	eval-rmse:1.27452
# [2450]	train-rmse:1.00085	eval-rmse:1.27447
# [2500]	train-rmse:0.998728	eval-rmse:1.27436
# [2550]	train-rmse:0.996929	eval-rmse:1.27437
# Stopping. Best iteration:
# [2500]	train-rmse:0.998728	eval-rmse:1.27436
#
# 0.2817729458331162 0.3231336235224723 0.34267587161588164 0.30357475085513497
# 0.3127892979566513

# %%
#学習結果のプロット
# %matplotlib inline
def plot_loss(evals_result, title):
    train_metric = evals_result['train']['rmse']
    plt.plot(train_metric, label='train rmse')
    eval_metric = evals_result['eval']['rmse']
    plt.plot(eval_metric, label='eval rmse')
    plt.grid()
    plt.legend()
    plt.title(title)
    plt.xlabel('rounds')
    plt.ylabel('rmse')
    plt.show()

# %%
for i in range(4):
    plot_loss(histories[i],f'Training Dataset: {i}')

# %%
test_length = len(test_data)
predict = np.array([0.0]*test_length)
dtest = xgb.DMatrix(test_x,label=test_y) #本来は学習に使用していないデータにする
for i in range(4):
    y_pred_proba = models[i].predict(dtest)
    predict += y_pred_proba

predict /= 4
# Out:
# C:\Anaconda3\lib\site-packages\xgboost\core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# C:\Anaconda3\lib\site-packages\xgboost\core.py:588: FutureWarning: Series.base is deprecated and will be removed in a future version
#   data.base is not None and isinstance(data, np.ndarray) \

# %%
y = pd.DataFrame(predict,columns=["y'"])
output = test_data #ここも書き換えること

output = pd.concat([output,y],axis=1)

output["複勝配当"] = output["複勝配当"].astype("int64")
output.to_csv("C:/programs/HRP/neweval.csv",index=False,encoding="shift-jis")

# %%
len(output)
# Out:
# 40422
