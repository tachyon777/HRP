# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import KFold
from sklearn.metrics import mean_squared_error
import xgboost as xgb
from matplotlib import pyplot as plt
from hyperopt import hp,fmin,tpe,STATUS_OK,Trials
import warnings
warnings.simplefilter('ignore')

# %%
data_dir = "F:/TARGET frontier/TXT33/"
data_name = "train"
tail = "fe5"
train_data = pd.read_csv(data_dir+data_name+tail+".csv",encoding="shift-jis",dtype={'レースID(旧)':str})

# %%
pd.set_option('display.max_columns', 100)
train_data.head()
# Out:
#    場所  芝・ダ    距離  クラス名  馬場状態  騎手コード  枠番  性別  年齢  キャリア    斤量   間隔  休み明け〜戦目  \
# 0   2    2  1200     2     3   5212   6   2   3    13  56.0  6.0      5.0
# 1   2    2  1200     2     3   5339   6   1   3    10  54.0  3.0      3.0
# 2   2    2  1200     2     3   5203   3   2   3     9  56.0  5.0      2.0
# 3   2    2  1200     2     3   1150   4   1   5    17  55.0  2.0      4.0
# 4   2    2  1200     2     3   1004   8   1   3    15  54.0  2.0      4.0
#
#    種牡馬  父タイプ名  調教師コード  前走場所  前芝・ダ     前距離  前クラス名  前走馬場状態  前走騎手コード  前走枠番  前走脚質  \
# 0  364      8    1105    13     2  1400.0      2       2    660.0   2.0     3
# 1  281      8    1002     1     2  1200.0      4       3   5339.0   7.0     3
# 2  387      5    1089     3     2  1200.0      2       3   1018.0   8.0     2
# 3   56      1    1134     2     2  1200.0      2       2   1150.0   6.0     2
# 4  193      4    1030     2     2  1200.0      2       2   1134.0   2.0     5
#
#    前走斤量  前走Ave-3F  前走上り3F  前走PCI3  前走RPCI  前PCI  前好走  前走平均1Fタイム  前走着差タイム  \
# 0  54.0      37.2    33.9   59.53    58.2  59.7    0      11.93      0.2
# 1  54.0      34.5    34.6   48.80    46.9  49.7    0      11.52      0.0
# 2  56.0      34.5    34.4   50.13    48.0  50.3    0      11.48      0.4
# 3  53.0      34.1    34.4   48.17    46.3  49.1    0      11.42      0.0
# 4  53.0      33.6    36.4   48.17    46.3  42.3    1      11.67      1.5
#
#    前走単勝オッズ   着差    レースID(旧)  複勝オッズ下限  複勝オッズ上限   複勝配当  単勝オッズ
# 0     14.6  0.0  0615581112      1.9      2.7  190.0    5.4
# 1      2.2  0.0  0615581111      1.3      1.6  130.0    2.8
# 2     28.6  0.2  0615581106      1.8      2.5  180.0    6.2
# 3     19.1  0.3  0615581108      1.7      2.5    0.0    6.6
# 4      8.6  0.3  0615581116      6.3      9.7    0.0   33.9

# %%
#test_data
test_data = pd.read_csv(data_dir+"predict2019"+tail+".csv",encoding="shift-jis",dtype={'レースID(旧)':str})
test_x = test_data.drop(["着差","レースID(旧)","複勝オッズ下限","複勝オッズ上限","複勝配当"],axis=1)
test_y = test_data["着差"]

# %%
train_x = train_data.drop(["着差","レースID(旧)","複勝オッズ下限","複勝オッズ上限","複勝配当"],axis=1)
train_y = train_data["着差"]

# %%
#ベースライン
params = {
    'booster':'gbtree',
    'objective':'reg:squarederror',
    'eta':0.1,
    'gamma':0.0,
    'alpha':0.0,
    'lambda':1.0,
    'min_child_weight':1,
    'max_depth':6,
    'subsample':0.8,
    'colsample_bytree':0.8,
    'random_state':71,
}

# %%
#正解ラベルの欠損値の穴埋め
#これがないとエラー履くので注意
train_y.fillna(1,inplace=True)
test_y.fillna(1,inplace=True)

# %%
def score(param_space):
    scores = []
    histories = []
    models = []
    
    for i,j in params.items():
        if i not in param_space:
            param_space[i] = j
    param_space['max_depth'] = int(param_space['max_depth'])
    print(param_space)    
    
    kf = KFold(n_splits=4,shuffle=False)
    for tr_idx,va_idx in kf.split(train_x):
        tr_x, va_x = train_x.iloc[tr_idx], train_x.iloc[va_idx]
        tr_y, va_y = train_y.iloc[tr_idx], train_y.iloc[va_idx]
        dtrain = xgb.DMatrix(tr_x,label=tr_y)
        dvalid = xgb.DMatrix(va_x,label=va_y)
        watchlist = [(dtrain,"train"),(dvalid,"eval")]
        evals_result = {}
        model = xgb.train(
            param_space,
            dtrain,
            num_boost_round=10000,
            early_stopping_rounds=100,
            evals=watchlist,
            evals_result=evals_result,
            verbose_eval=100
        )
        models.append(model)
        histories.append(evals_result)
        va_pred = model.predict(dvalid)
        va_y.fillna(0.5,inplace=True)
        #print(va_pred[:10])
        #print(va_y[:10])
        score = np.sqrt(mean_squared_error(va_y,va_pred)) #rmse
        scores.append(score)
    rmse_score = np.mean(scores)
    history_opt.append((param_space,rmse_score))
    
    return {"loss": score, "status": STATUS_OK}

# %%
#パラメータチューニング
param_space = {

    'min_child_weight': hp.loguniform('min_child_weight', np.log(0.1), np.log(10)),

    'max_depth': hp.quniform('max_depth', 3, 9, 1),

    'subsample': hp.quniform('subsample', 0.6, 0.95, 0.05),

    'colsample_bytree': hp.quniform('colsample_bytree', 0.6, 0.95, 0.05),

    'gamma': hp.loguniform('gamma', np.log(1e-8), np.log(1.0)),

    # 余裕があればalpha, lambdaも調整する

    # 'alpha' : hp.loguniform('alpha', np.log(1e-8), np.log(1.0)),

    # 'lambda' : hp.loguniform('lambda', np.log(1e-6), np.log(10.0)),

}

# %%
max_evals = 10
trials = Trials()
history_opt = []
fmin(score,param_space,algo=tpe.suggest,trials=trials,max_evals=max_evals) #パラメータチューニングの実行
# Out:
# {'colsample_bytree': 0.65, 'gamma': 0.013439667332810353, 'max_depth': 5, 'min_child_weight': 2.663317188920419, 'subsample': 0.9, 'booster': 'gbtree', 'objective': 'reg:squarederror', 'eta': 0.1, 'alpha': 0.0, 'lambda': 1.0, 'random_state': 71}
# [0]	train-rmse:1.61655	eval-rmse:1.61827
#
# Multiple eval metrics have been passed: 'eval-rmse' will be used for early stopping.
#
#
# Will train until eval-rmse hasn't improved in 50 rounds.
#
# [100]	train-rmse:1.10196	eval-rmse:1.22578
#
# [200]	train-rmse:1.06734	eval-rmse:1.22561
#
# Stopping. Best iteration:
# [155]	train-rmse:1.08224	eval-rmse:1.22439
#
#
# [0]	train-rmse:1.62114	eval-rmse:1.60468
#
# Multiple eval metrics have been passed: 'eval-rmse' will be used for early stopping.
#
#
# Will train until eval-rmse hasn't improved in 50 rounds.
#
# [100]	train-rmse:1.10574	eval-rmse:1.17061
#
# Stopping. Best iteration:
# [86]	train-rmse:1.11423	eval-rmse:1.17016
#
#
# [0]	train-rmse:1.6403	eval-rmse:1.54413
#
# Multiple eval metrics have been passed: 'eval-rmse' will be used for early stopping.
#
#
# Will train until eval-rmse hasn't improved in 50 rounds.
#
# [100]	train-rmse:1.12287	eval-rmse:1.09645
#
# Stopping. Best iteration:
# [90]	train-rmse:1.13047	eval-rmse:1.0963
#
#
# [0]	train-rmse:1.58929	eval-rmse:1.70032
#
# Multiple eval metrics have been passed: 'eval-rmse' will be used for early stopping.
#
#
# Will train until eval-rmse hasn't improved in 50 rounds.
#
# [100]	train-rmse:1.08953	eval-rmse:1.24043
#
# Stopping. Best iteration:
# [96]	train-rmse:1.0914	eval-rmse:1.24008
#
#
# {'colsample_bytree': 0.65, 'gamma': 4.724721130184604e-05, 'max_depth': 7, 'min_child_weight': 0.3139778483103001, 'subsample': 0.65, 'booster': 'gbtree', 'objective': 'reg:squarederror', 'eta': 0.1, 'alpha': 0.0, 'lambda': 1.0, 'random_state': 71}
# [0]	train-rmse:1.6113	eval-rmse:1.61502
#
# Multiple eval metrics have been passed: 'eval-rmse' will be used for early stopping.
#
#
# Will train until eval-rmse hasn't improved in 50 rounds.
#
# Stopping. Best iteration:
# [46]	train-rmse:1.05978	eval-rmse:1.22832
#
#
# [0]	train-rmse:1.61555	eval-rmse:1.60203
#
# Multiple eval metrics have been passed: 'eval-rmse' will be used for early stopping.
#
#
# Will train until eval-rmse hasn't improved in 50 rounds.
#
# [100]	train-rmse:1.01022	eval-rmse:1.17669
#
# Stopping. Best iteration:
# [77]	train-rmse:1.0286	eval-rmse:1.17566
#
#
# [0]	train-rmse:1.63403	eval-rmse:1.54152
#
# Multiple eval metrics have been passed: 'eval-rmse' will be used for early stopping.
#
#
# Will train until eval-rmse hasn't improved in 50 rounds.
#
# [100]	train-rmse:1.01692	eval-rmse:1.10222
#
# Stopping. Best iteration:
# [62]	train-rmse:1.05455	eval-rmse:1.10091
#
#
# [0]	train-rmse:1.58444	eval-rmse:1.69701
#
# Multiple eval metrics have been passed: 'eval-rmse' will be used for early stopping.
#
#
# Will train until eval-rmse hasn't improved in 50 rounds.
#
# [100]	train-rmse:0.993023	eval-rmse:1.24721
#
# Stopping. Best iteration:
# [66]	train-rmse:1.01919	eval-rmse:1.24535
#
#
# {'colsample_bytree': 0.8, 'gamma': 9.752681049064432e-08, 'max_depth': 4, 'min_child_weight': 0.6351847375492726, 'subsample': 0.7000000000000001, 'booster': 'gbtree', 'objective': 'reg:squarederror', 'eta': 0.1, 'alpha': 0.0, 'lambda': 1.0, 'random_state': 71}
# [0]	train-rmse:1.61964	eval-rmse:1.62086
#
# Multiple eval metrics have been passed: 'eval-rmse' will be used for early stopping.
#
#
# Will train until eval-rmse hasn't improved in 50 rounds.
#
# [100]	train-rmse:1.12948	eval-rmse:1.22648
#
# [200]	train-rmse:1.09899	eval-rmse:1.22714
#
# Stopping. Best iteration:
# [164]	train-rmse:1.11112	eval-rmse:1.22475
#
#
# [0]	train-rmse:1.62408	eval-rmse:1.60651
#
# Multiple eval metrics have been passed: 'eval-rmse' will be used for early stopping.
#
#
# Will train until eval-rmse hasn't improved in 50 rounds.
#
# [100]	train-rmse:1.13429	eval-rmse:1.17468
#
# [200]	train-rmse:1.10174	eval-rmse:1.17273
#
# Stopping. Best iteration:
# [176]	train-rmse:1.10876	eval-rmse:1.17238
#
#
# [0]	train-rmse:1.6436	eval-rmse:1.54715
#
# Multiple eval metrics have been passed: 'eval-rmse' will be used for early stopping.
#
#
# Will train until eval-rmse hasn't improved in 50 rounds.
#
# [100]	train-rmse:1.15674	eval-rmse:1.09789
#
# Stopping. Best iteration:
# [130]	train-rmse:1.14458	eval-rmse:1.0967
#
#
# [0]	train-rmse:1.59271	eval-rmse:1.70379
#
# Multiple eval metrics have been passed: 'eval-rmse' will be used for early stopping.
#
#
# Will train until eval-rmse hasn't improved in 50 rounds.
#
# [100]	train-rmse:1.1169	eval-rmse:1.24054
#
# [200]	train-rmse:1.08596	eval-rmse:1.23714
#
# Stopping. Best iteration:
# [196]	train-rmse:1.08715	eval-rmse:1.23669
#
#
# {'colsample_bytree': 0.9, 'gamma': 0.0003587129645036146, 'max_depth': 9, 'min_child_weight': 0.21259883951941905, 'subsample': 0.65, 'booster': 'gbtree', 'objective': 'reg:squarederror', 'eta': 0.1, 'alpha': 0.0, 'lambda': 1.0, 'random_state': 71}
# [0]	train-rmse:1.60605	eval-rmse:1.61309
#
# Multiple eval metrics have been passed: 'eval-rmse' will be used for early stopping.
#
#
# Will train until eval-rmse hasn't improved in 50 rounds.
#
# Stopping. Best iteration:
# [31]	train-rmse:1.00069	eval-rmse:1.23501
#
#
# [0]	train-rmse:1.61043	eval-rmse:1.59985
#
# Multiple eval metrics have been passed: 'eval-rmse' will be used for early stopping.
#
#
# Will train until eval-rmse hasn't improved in 50 rounds.
#
# Stopping. Best iteration:
# [33]	train-rmse:1.00202	eval-rmse:1.1837
#
#
# [0]	train-rmse:1.62933	eval-rmse:1.53991
#
# Multiple eval metrics have been passed: 'eval-rmse' will be used for early stopping.
#
#
# Will train until eval-rmse hasn't improved in 50 rounds.
#
# Stopping. Best iteration:
# [47]	train-rmse:0.966733	eval-rmse:1.10637
#
#
# [0]	train-rmse:1.57861	eval-rmse:1.69547
#
# Multiple eval metrics have been passed: 'eval-rmse' will be used for early stopping.
#
#
# Will train until eval-rmse hasn't improved in 50 rounds.
#
# [100]	train-rmse:0.861104	eval-rmse:1.25163
#
# Stopping. Best iteration:
# [50]	train-rmse:0.933752	eval-rmse:1.24814
#
#
# {'colsample_bytree': 0.9, 'gamma': 0.00018287715070890276, 'max_depth': 8, 'min_child_weight': 1.9333960116774207, 'subsample': 0.9, 'booster': 'gbtree', 'objective': 'reg:squarederror', 'eta': 0.1, 'alpha': 0.0, 'lambda': 1.0, 'random_state': 71}
# [0]	train-rmse:1.607	eval-rmse:1.61277
#
# Multiple eval metrics have been passed: 'eval-rmse' will be used for early stopping.
#
#
# Will train until eval-rmse hasn't improved in 50 rounds.
#
# Stopping. Best iteration:
# [42]	train-rmse:1.01863	eval-rmse:1.23195
#
#
# [0]	train-rmse:1.61095	eval-rmse:1.59844
#
# Multiple eval metrics have been passed: 'eval-rmse' will be used for early stopping.
#
#
# Will train until eval-rmse hasn't improved in 50 rounds.
#
# [100]	train-rmse:0.940311	eval-rmse:1.17915
#
# Stopping. Best iteration:
# [62]	train-rmse:0.984725	eval-rmse:1.17632
#
#
# [0]	train-rmse:1.62948	eval-rmse:1.54002
#
# Multiple eval metrics have been passed: 'eval-rmse' will be used for early stopping.
#
#
# Will train until eval-rmse hasn't improved in 50 rounds.
#
# Stopping. Best iteration:
# [41]	train-rmse:1.02742	eval-rmse:1.10002
#
#
# [0]	train-rmse:1.57902	eval-rmse:1.69528
#
# Multiple eval metrics have been passed: 'eval-rmse' will be used for early stopping.
#
#
# Will train until eval-rmse hasn't improved in 50 rounds.
#
# [100]	train-rmse:0.920227	eval-rmse:1.25289
#
# Stopping. Best iteration:
# [55]	train-rmse:0.972112	eval-rmse:1.25153
#
#
# {'colsample_bytree': 0.65, 'gamma': 1.5179030923788695e-07, 'max_depth': 7, 'min_child_weight': 2.00025209699263, 'subsample': 0.8, 'booster': 'gbtree', 'objective': 'reg:squarederror', 'eta': 0.1, 'alpha': 0.0, 'lambda': 1.0, 'random_state': 71}
# [0]	train-rmse:1.6114	eval-rmse:1.61487
#
# Multiple eval metrics have been passed: 'eval-rmse' will be used for early stopping.
#
#
# Will train until eval-rmse hasn't improved in 50 rounds.
#
# [100]	train-rmse:1.01647	eval-rmse:1.23245
#
# Stopping. Best iteration:
# [51]	train-rmse:1.06206	eval-rmse:1.23162
#
#
# [0]	train-rmse:1.61574	eval-rmse:1.60105
#
# Multiple eval metrics have been passed: 'eval-rmse' will be used for early stopping.
#
#
# Will train until eval-rmse hasn't improved in 50 rounds.
#
# [100]	train-rmse:1.01814	eval-rmse:1.17219
#
# Stopping. Best iteration:
# [72]	train-rmse:1.04202	eval-rmse:1.17134
#
#
# [0]	train-rmse:1.63445	eval-rmse:1.54021
#
# Multiple eval metrics have been passed: 'eval-rmse' will be used for early stopping.
#
#
# Will train until eval-rmse hasn't improved in 50 rounds.
#
# [100]	train-rmse:1.02704	eval-rmse:1.10108
#
# Stopping. Best iteration:
# [67]	train-rmse:1.05723	eval-rmse:1.09943
#
#
# [0]	train-rmse:1.58366	eval-rmse:1.69662
#
# Multiple eval metrics have been passed: 'eval-rmse' will be used for early stopping.
#
#
# Will train until eval-rmse hasn't improved in 50 rounds.
#
# [100]	train-rmse:0.997524	eval-rmse:1.24307
#
# Stopping. Best iteration:
# [104]	train-rmse:0.994977	eval-rmse:1.24272
#
#
# {'colsample_bytree': 0.9500000000000001, 'gamma': 3.207270488778453e-05, 'max_depth': 9, 'min_child_weight': 1.1782462698899345, 'subsample': 0.8, 'booster': 'gbtree', 'objective': 'reg:squarederror', 'eta': 0.1, 'alpha': 0.0, 'lambda': 1.0, 'random_state': 71}
# [0]	train-rmse:1.6058	eval-rmse:1.61317
#
# Multiple eval metrics have been passed: 'eval-rmse' will be used for early stopping.
#
#
# Will train until eval-rmse hasn't improved in 50 rounds.
#
# Stopping. Best iteration:
# [35]	train-rmse:0.985344	eval-rmse:1.23394
#
#
# [0]	train-rmse:1.60884	eval-rmse:1.5988
#
# Multiple eval metrics have been passed: 'eval-rmse' will be used for early stopping.
#
#
# Will train until eval-rmse hasn't improved in 50 rounds.
#
# Stopping. Best iteration:
# [46]	train-rmse:0.960095	eval-rmse:1.17825
#
#
# [0]	train-rmse:1.62753	eval-rmse:1.54043
#
# Multiple eval metrics have been passed: 'eval-rmse' will be used for early stopping.
#
#
# Will train until eval-rmse hasn't improved in 50 rounds.
#
# Stopping. Best iteration:
# [35]	train-rmse:0.998292	eval-rmse:1.10908
#
#
# [0]	train-rmse:1.5768	eval-rmse:1.69493
#
# Multiple eval metrics have been passed: 'eval-rmse' will be used for early stopping.
#
#
# Will train until eval-rmse hasn't improved in 50 rounds.
#
# Stopping. Best iteration:
# [38]	train-rmse:0.95995	eval-rmse:1.25534
#
#
# {'colsample_bytree': 0.9500000000000001, 'gamma': 2.3546724750804604e-06, 'max_depth': 7, 'min_child_weight': 0.11945919630396418, 'subsample': 0.75, 'booster': 'gbtree', 'objective': 'reg:squarederror', 'eta': 0.1, 'alpha': 0.0, 'lambda': 1.0, 'random_state': 71}
# [0]	train-rmse:1.60971	eval-rmse:1.61352
#
# Multiple eval metrics have been passed: 'eval-rmse' will be used for early stopping.
#
#
# Will train until eval-rmse hasn't improved in 50 rounds.
#
# Stopping. Best iteration:
# [34]	train-rmse:1.07319	eval-rmse:1.23243
#
#
# [0]	train-rmse:1.61267	eval-rmse:1.60035
#
# Multiple eval metrics have been passed: 'eval-rmse' will be used for early stopping.
#
#
# Will train until eval-rmse hasn't improved in 50 rounds.
#
# [100]	train-rmse:1.00206	eval-rmse:1.17606
#
# Stopping. Best iteration:
# [52]	train-rmse:1.0468	eval-rmse:1.17459
#
#
# [0]	train-rmse:1.63206	eval-rmse:1.54006
#
# Multiple eval metrics have been passed: 'eval-rmse' will be used for early stopping.
#
#
# Will train until eval-rmse hasn't improved in 50 rounds.
#
# Stopping. Best iteration:
# [45]	train-rmse:1.06936	eval-rmse:1.09864
#
#
# [0]	train-rmse:1.581	eval-rmse:1.69562
#
# Multiple eval metrics have been passed: 'eval-rmse' will be used for early stopping.
#
#
# Will train until eval-rmse hasn't improved in 50 rounds.
#
# [100]	train-rmse:0.979013	eval-rmse:1.25059
#
# Stopping. Best iteration:
# [99]	train-rmse:0.979828	eval-rmse:1.25051
#
#
# {'colsample_bytree': 0.8500000000000001, 'gamma': 0.02053814743838391, 'max_depth': 5, 'min_child_weight': 4.7264262229514875, 'subsample': 0.9, 'booster': 'gbtree', 'objective': 'reg:squarederror', 'eta': 0.1, 'alpha': 0.0, 'lambda': 1.0, 'random_state': 71}
# [0]	train-rmse:1.61632	eval-rmse:1.61814
#
# Multiple eval metrics have been passed: 'eval-rmse' will be used for early stopping.
#
#
# Will train until eval-rmse hasn't improved in 50 rounds.
#
# [100]	train-rmse:1.10767	eval-rmse:1.22623
#
# Stopping. Best iteration:
# [113]	train-rmse:1.1025	eval-rmse:1.22605
#
#
# [0]	train-rmse:1.62037	eval-rmse:1.60362
#
# Multiple eval metrics have been passed: 'eval-rmse' will be used for early stopping.
#
#
# Will train until eval-rmse hasn't improved in 50 rounds.
#
# [100]	train-rmse:1.11153	eval-rmse:1.17276
#
# Stopping. Best iteration:
# [115]	train-rmse:1.10535	eval-rmse:1.17181
#
#
# [0]	train-rmse:1.64004	eval-rmse:1.54423
#
# Multiple eval metrics have been passed: 'eval-rmse' will be used for early stopping.
#
#
# Will train until eval-rmse hasn't improved in 50 rounds.
#
# [100]	train-rmse:1.13172	eval-rmse:1.09672
#
# Stopping. Best iteration:
# [99]	train-rmse:1.13221	eval-rmse:1.09649
#
#
# [0]	train-rmse:1.58893	eval-rmse:1.70051
#
# Multiple eval metrics have been passed: 'eval-rmse' will be used for early stopping.
#
#
# Will train until eval-rmse hasn't improved in 50 rounds.
#
# [100]	train-rmse:1.09236	eval-rmse:1.24151
#
# [200]	train-rmse:1.05541	eval-rmse:1.2422
#
# Stopping. Best iteration:
# [161]	train-rmse:1.06889	eval-rmse:1.24096
#
#
# {'colsample_bytree': 0.9, 'gamma': 2.0734739734271457e-08, 'max_depth': 5, 'min_child_weight': 3.0151860663691803, 'subsample': 0.7000000000000001, 'booster': 'gbtree', 'objective': 'reg:squarederror', 'eta': 0.1, 'alpha': 0.0, 'lambda': 1.0, 'random_state': 71}
# [0]	train-rmse:1.61522	eval-rmse:1.61673
#
# Multiple eval metrics have been passed: 'eval-rmse' will be used for early stopping.
#
#
# Will train until eval-rmse hasn't improved in 50 rounds.
#
# [100]	train-rmse:1.10134	eval-rmse:1.22543
#
# [200]	train-rmse:1.06534	eval-rmse:1.2252
#
# Stopping. Best iteration:
# [164]	train-rmse:1.07625	eval-rmse:1.22424
#
#
# [0]	train-rmse:1.62015	eval-rmse:1.60283
#
# Multiple eval metrics have been passed: 'eval-rmse' will be used for early stopping.
#
#
# Will train until eval-rmse hasn't improved in 50 rounds.
#
# [100]	train-rmse:1.11203	eval-rmse:1.17153
#
# Stopping. Best iteration:
# [83]	train-rmse:1.12123	eval-rmse:1.17131
#
#
# [0]	train-rmse:1.63942	eval-rmse:1.54395
#
# Multiple eval metrics have been passed: 'eval-rmse' will be used for early stopping.
#
#
# Will train until eval-rmse hasn't improved in 50 rounds.
#
# [100]	train-rmse:1.12578	eval-rmse:1.09891
#
# Stopping. Best iteration:
# [114]	train-rmse:1.11928	eval-rmse:1.09841
#
#
# [0]	train-rmse:1.58869	eval-rmse:1.69991
#
# Multiple eval metrics have been passed: 'eval-rmse' will be used for early stopping.
#
#
# Will train until eval-rmse hasn't improved in 50 rounds.
#
# [100]	train-rmse:1.09181	eval-rmse:1.24442
#
# Stopping. Best iteration:
# [136]	train-rmse:1.0754	eval-rmse:1.24327
#
#
# 100%|████████████████████████████████████████████████| 10/10 [06:02<00:00, 36.23s/trial, best loss: 1.2372074824898776]
# {'colsample_bytree': 0.8,
#  'gamma': 9.752681049064432e-08,
#  'max_depth': 4.0,
#  'min_child_weight': 0.6351847375492726,
#  'subsample': 0.7000000000000001}

# %%
#記録した情報からパラメータとスコアを取得
history_opt = sorted(history_opt,key=lambda tpl: tpl[1])
best = history_opt[0]
print(f"best params:{best[0]}, score:{best[1]:.4f}")
# Out:
# best params:{'colsample_bytree': 0.65, 'gamma': 0.013439667332810353, 'max_depth': 5, 'min_child_weight': 2.663317188920419, 'subsample': 0.9, 'booster': 'gbtree', 'objective': 'reg:squarederror', 'eta': 0.1, 'alpha': 0.0, 'lambda': 1.0, 'random_state': 71}, score:1.1834

# %%
history_opt
# Out:
# [({'colsample_bytree': 0.65,
#    'gamma': 0.013439667332810353,
#    'max_depth': 5,
#    'min_child_weight': 2.663317188920419,
#    'subsample': 0.9,
#    'booster': 'gbtree',
#    'objective': 'reg:squarederror',
#    'eta': 0.1,
#    'alpha': 0.0,
#    'lambda': 1.0,
#    'random_state': 71},
#   1.1834036403467327),
#  ({'colsample_bytree': 0.8,
#    'gamma': 9.752681049064432e-08,
#    'max_depth': 4,
#    'min_child_weight': 0.6351847375492726,
#    'subsample': 0.7000000000000001,
#    'booster': 'gbtree',
#    'objective': 'reg:squarederror',
#    'eta': 0.1,
#    'alpha': 0.0,
#    'lambda': 1.0,
#    'random_state': 71},
#   1.1837693429954388),
#  ({'colsample_bytree': 0.8500000000000001,
#    'gamma': 0.02053814743838391,
#    'max_depth': 5,
#    'min_child_weight': 4.7264262229514875,
#    'subsample': 0.9,
#    'booster': 'gbtree',
#    'objective': 'reg:squarederror',
#    'eta': 0.1,
#    'alpha': 0.0,
#    'lambda': 1.0,
#    'random_state': 71},
#   1.184767132215382),
#  ({'colsample_bytree': 0.9,
#    'gamma': 2.0734739734271457e-08,
#    'max_depth': 5,
#    'min_child_weight': 3.0151860663691803,
#    'subsample': 0.7000000000000001,
#    'booster': 'gbtree',
#    'objective': 'reg:squarederror',
#    'eta': 0.1,
#    'alpha': 0.0,
#    'lambda': 1.0,
#    'random_state': 71},
#   1.1856419618867107),
#  ({'colsample_bytree': 0.65,
#    'gamma': 1.5179030923788695e-07,
#    'max_depth': 7,
#    'min_child_weight': 2.00025209699263,
#    'subsample': 0.8,
#    'booster': 'gbtree',
#    'objective': 'reg:squarederror',
#    'eta': 0.1,
#    'alpha': 0.0,
#    'lambda': 1.0,
#    'random_state': 71},
#   1.187990490393893),
#  ({'colsample_bytree': 0.65,
#    'gamma': 4.724721130184604e-05,
#    'max_depth': 7,
#    'min_child_weight': 0.3139778483103001,
#    'subsample': 0.65,
#    'booster': 'gbtree',
#    'objective': 'reg:squarederror',
#    'eta': 0.1,
#    'alpha': 0.0,
#    'lambda': 1.0,
#    'random_state': 71},
#   1.1895422788851204),
#  ({'colsample_bytree': 0.9500000000000001,
#    'gamma': 2.3546724750804604e-06,
#    'max_depth': 7,
#    'min_child_weight': 0.11945919630396418,
#    'subsample': 0.75,
#    'booster': 'gbtree',
#    'objective': 'reg:squarederror',
#    'eta': 0.1,
#    'alpha': 0.0,
#    'lambda': 1.0,
#    'random_state': 71},
#   1.1909453739420284),
#  ({'colsample_bytree': 0.9,
#    'gamma': 0.00018287715070890276,
#    'max_depth': 8,
#    'min_child_weight': 1.9333960116774207,
#    'subsample': 0.9,
#    'booster': 'gbtree',
#    'objective': 'reg:squarederror',
#    'eta': 0.1,
#    'alpha': 0.0,
#    'lambda': 1.0,
#    'random_state': 71},
#   1.1922982279904828),
#  ({'colsample_bytree': 0.9,
#    'gamma': 0.0003587129645036146,
#    'max_depth': 9,
#    'min_child_weight': 0.21259883951941905,
#    'subsample': 0.65,
#    'booster': 'gbtree',
#    'objective': 'reg:squarederror',
#    'eta': 0.1,
#    'alpha': 0.0,
#    'lambda': 1.0,
#    'random_state': 71},
#   1.1972435959845074),
#  ({'colsample_bytree': 0.9500000000000001,
#    'gamma': 3.207270488778453e-05,
#    'max_depth': 9,
#    'min_child_weight': 1.1782462698899345,
#    'subsample': 0.8,
#    'booster': 'gbtree',
#    'objective': 'reg:squarederror',
#    'eta': 0.1,
#    'alpha': 0.0,
#    'lambda': 1.0,
#    'random_state': 71},
#   1.1980312751138218)]

# %%
#学習結果のプロット
# %matplotlib inline
def plot_loss(evals_result, title):
    train_metric = evals_result['train']['rmse']
    plt.plot(train_metric, label='train rmse')
    eval_metric = evals_result['eval']['rmse']
    plt.plot(eval_metric, label='eval rmse')
    plt.grid()
    plt.legend()
    plt.title(title)
    plt.xlabel('rounds')
    plt.ylabel('rmse')
    plt.show()

# %%
for i in range(4):
    plot_loss(histories[i],f'Training Dataset: {i}')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-82f34766c8c0> in <module>
#       1 for i in range(4):
# ----> 2     plot_loss(histories[i],f'Training Dataset: {i}')
#
# NameError: name 'histories' is not defined

# %%
test_length = len(test_data)
predict = np.array([0.0]*test_length)
dtest = xgb.DMatrix(test_x,label=test_y) #本来は学習に使用していないデータにする
for i in range(4):
    y_pred_proba = models[i].predict(dtest)
    predict += y_pred_proba

predict /= 4

# %%
y = pd.DataFrame(predict,columns=["y'"])
output = test_data #ここも書き換えること

output = pd.concat([output,y],axis=1)

output["複勝配当"] = output["複勝配当"].astype("int64")
output.to_csv("C:/programs/HRP/neweval.csv",index=False,encoding="shift-jis")

# %%
len(output)
