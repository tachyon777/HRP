# %% [markdown]
# ver0.0.2-optのチューニングしたパラメータを用いて学習を行う。

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import KFold
from sklearn.metrics import mean_squared_error
import xgboost as xgb
from matplotlib import pyplot as plt
import warnings
warnings.simplefilter('ignore')

# %%
data_dir = "F:/TARGET frontier/TXT33/"
data_name = "train"
tail = "fe5"
train_data = pd.read_csv(data_dir+data_name+tail+".csv",encoding="shift-jis",dtype={'レースID(旧)':str})

# %%
pd.set_option('display.max_columns', 100)
train_data.head()
# Out:
#    場所  芝・ダ    距離  クラス名  馬場状態  騎手コード  枠番  性別  年齢  キャリア    斤量   間隔  休み明け〜戦目  \
# 0   2    2  1200     2     3   5212   6   2   3    13  56.0  6.0      5.0
# 1   2    2  1200     2     3   5339   6   1   3    10  54.0  3.0      3.0
# 2   2    2  1200     2     3   5203   3   2   3     9  56.0  5.0      2.0
# 3   2    2  1200     2     3   1150   4   1   5    17  55.0  2.0      4.0
# 4   2    2  1200     2     3   1004   8   1   3    15  54.0  2.0      4.0
#
#    種牡馬  父タイプ名  調教師コード  前走場所  前芝・ダ     前距離  前クラス名  前走馬場状態  前走騎手コード  前走枠番  前走脚質  \
# 0  572      8    1105    13     2  1400.0      2       2    660.0   2.0     3
# 1  452      8    1002     1     2  1200.0      7       3   5339.0   7.0     3
# 2  607      5    1089     3     2  1200.0      2       3   1018.0   8.0     2
# 3   91      1    1134     2     2  1200.0      2       2   1150.0   6.0     2
# 4  325      4    1030     2     2  1200.0      2       2   1134.0   2.0     5
#
#    前走斤量  前走Ave-3F  前走上り3F  前走PCI3  前走RPCI  前PCI  前好走  前走平均1Fタイム  前走着差タイム  \
# 0  54.0      37.2    33.9   59.53    58.2  59.7    0      11.93      0.2
# 1  54.0      34.5    34.6   48.80    46.9  49.7    0      11.52      0.0
# 2  56.0      34.5    34.4   50.13    48.0  50.3    0      11.48      0.4
# 3  53.0      34.1    34.4   48.17    46.3  49.1    0      11.42      0.0
# 4  53.0      33.6    36.4   48.17    46.3  42.3    1      11.67      1.5
#
#    前走単勝オッズ   着差    レースID(旧)  複勝オッズ下限  複勝オッズ上限   複勝配当  単勝オッズ
# 0     14.6  0.0  0615581112      1.9      2.7  190.0    5.4
# 1      2.2  0.0  0615581111      1.3      1.6  130.0    2.8
# 2     28.6  0.2  0615581106      1.8      2.5  180.0    6.2
# 3     19.1  0.3  0615581108      1.7      2.5    0.0    6.6
# 4      8.6  0.3  0615581116      6.3      9.7    0.0   33.9

# %%
#test_data
test_data = pd.read_csv(data_dir+"predict"+tail+".csv",encoding="shift-jis",dtype={'レースID(旧)':str})
test_x = test_data.drop(["着差","レースID(旧)","複勝オッズ下限","複勝オッズ上限","複勝配当"],axis=1)
test_y = test_data["着差"]

# %%
train_x = train_data.drop(["着差","レースID(旧)","複勝オッズ下限","複勝オッズ上限","複勝配当"],axis=1)
train_y = train_data["着差"]

# %%
#チューニング済みパラメータ(etaのみ手動)
params = {'colsample_bytree': 0.65, 
          'gamma': 0.013439667332810353, 
          'max_depth': 5, 
          'min_child_weight': 2.663317188920419, 
          'subsample': 0.9, 
          'booster': 'gbtree', 
          'objective': 'reg:squarederror', 
          'eta': 0.005, 
          'alpha': 0.0, 
          'lambda': 1.0, 
          'random_state': 71}

# %%
#これがないとエラー履くので注意
train_y.fillna(1,inplace=True)
test_y.fillna(1,inplace=True)

# %%
scores = []
histories = []
models = []
kf = KFold(n_splits=4,shuffle=False)
for tr_idx,va_idx in kf.split(train_x):
    tr_x, va_x = train_x.iloc[tr_idx], train_x.iloc[va_idx]
    tr_y, va_y = train_y.iloc[tr_idx], train_y.iloc[va_idx]
    dtrain = xgb.DMatrix(tr_x,label=tr_y)
    dvalid = xgb.DMatrix(va_x,label=va_y)
    watchlist = [(dtrain,"train"),(dvalid,"eval")]
    evals_result = {}
    model = xgb.train(
        params,
        dtrain,
        num_boost_round=10000,
        early_stopping_rounds=100,
        evals=watchlist,
        evals_result=evals_result,
        verbose_eval=100
    )
    models.append(model)
    histories.append(evals_result)
    va_pred = model.predict(dvalid)
    va_y.fillna(0.5,inplace=True) #ここまでok
    #print(va_pred[:10])
    #print(va_y[:10])
    score = mean_squared_error(va_y,va_pred)
    score = np.sqrt(mean_squared_error(va_y,va_pred)) #rmse
    scores.append(score)

print(*scores)
print(np.mean(scores))
# Out:
# [0]	train-rmse:1.69015	eval-rmse:1.6852
# Multiple eval metrics have been passed: 'eval-rmse' will be used for early stopping.
#
# Will train until eval-rmse hasn't improved in 100 rounds.
# [100]	train-rmse:1.41681	eval-rmse:1.44094
# [200]	train-rmse:1.2868	eval-rmse:1.33037
# [300]	train-rmse:1.22215	eval-rmse:1.27888
# [400]	train-rmse:1.18943	eval-rmse:1.25514
# [500]	train-rmse:1.17043	eval-rmse:1.24299
# [600]	train-rmse:1.15792	eval-rmse:1.23632
# [700]	train-rmse:1.14911	eval-rmse:1.23243
# [800]	train-rmse:1.14248	eval-rmse:1.22983
# [900]	train-rmse:1.13721	eval-rmse:1.22798
# [1000]	train-rmse:1.13272	eval-rmse:1.22668
# [1100]	train-rmse:1.12864	eval-rmse:1.2256
# [1200]	train-rmse:1.12499	eval-rmse:1.22496
# [1300]	train-rmse:1.12172	eval-rmse:1.2243
# [1400]	train-rmse:1.1187	eval-rmse:1.22369
# [1500]	train-rmse:1.11568	eval-rmse:1.22321
# [1600]	train-rmse:1.11283	eval-rmse:1.22289
# [1700]	train-rmse:1.11028	eval-rmse:1.22257
# [1800]	train-rmse:1.10775	eval-rmse:1.22234
# [1900]	train-rmse:1.10546	eval-rmse:1.22211
# [2000]	train-rmse:1.10314	eval-rmse:1.22198
# [2100]	train-rmse:1.10095	eval-rmse:1.22179
# [2200]	train-rmse:1.09869	eval-rmse:1.22166
# [2300]	train-rmse:1.09638	eval-rmse:1.22159
# [2400]	train-rmse:1.09435	eval-rmse:1.22147
# [2500]	train-rmse:1.09213	eval-rmse:1.22135
# [2600]	train-rmse:1.09009	eval-rmse:1.22134
# Stopping. Best iteration:
# [2529]	train-rmse:1.09153	eval-rmse:1.22129
#
# [0]	train-rmse:1.69312	eval-rmse:1.67623
# Multiple eval metrics have been passed: 'eval-rmse' will be used for early stopping.
#
# Will train until eval-rmse hasn't improved in 100 rounds.
# [100]	train-rmse:1.42636	eval-rmse:1.41469
# [200]	train-rmse:1.29898	eval-rmse:1.29341
# [300]	train-rmse:1.23591	eval-rmse:1.23526
# [400]	train-rmse:1.20311	eval-rmse:1.20785
# [500]	train-rmse:1.18319	eval-rmse:1.19354
# [600]	train-rmse:1.16981	eval-rmse:1.18518
# [700]	train-rmse:1.16054	eval-rmse:1.18047
# [800]	train-rmse:1.15299	eval-rmse:1.17713
# [900]	train-rmse:1.1471	eval-rmse:1.17488
# [1000]	train-rmse:1.1419	eval-rmse:1.17308
# [1100]	train-rmse:1.13689	eval-rmse:1.17163
# [1200]	train-rmse:1.13251	eval-rmse:1.17048
# [1300]	train-rmse:1.12855	eval-rmse:1.16944
# [1400]	train-rmse:1.12479	eval-rmse:1.16857
# [1500]	train-rmse:1.1211	eval-rmse:1.16782
# [1600]	train-rmse:1.11771	eval-rmse:1.16722
# [1700]	train-rmse:1.11453	eval-rmse:1.16673
# [1800]	train-rmse:1.11157	eval-rmse:1.16631
# [1900]	train-rmse:1.10891	eval-rmse:1.16598
# [2000]	train-rmse:1.10639	eval-rmse:1.16567
# [2100]	train-rmse:1.10397	eval-rmse:1.1654
# [2200]	train-rmse:1.10134	eval-rmse:1.16515
# [2300]	train-rmse:1.09915	eval-rmse:1.16492
# [2400]	train-rmse:1.09682	eval-rmse:1.16468
# [2500]	train-rmse:1.09468	eval-rmse:1.16444
# [2600]	train-rmse:1.09256	eval-rmse:1.16422
# [2700]	train-rmse:1.09063	eval-rmse:1.16408
# [2800]	train-rmse:1.08865	eval-rmse:1.16391
# [2900]	train-rmse:1.08668	eval-rmse:1.16382
# [3000]	train-rmse:1.08478	eval-rmse:1.16372
# [3100]	train-rmse:1.08293	eval-rmse:1.16356
# [3200]	train-rmse:1.08105	eval-rmse:1.16349
# [3300]	train-rmse:1.07926	eval-rmse:1.16341
# [3400]	train-rmse:1.07744	eval-rmse:1.16333
# [3500]	train-rmse:1.07556	eval-rmse:1.16326
# [3600]	train-rmse:1.07376	eval-rmse:1.16318
# [3700]	train-rmse:1.07204	eval-rmse:1.16313
# [3800]	train-rmse:1.07035	eval-rmse:1.16307
# Stopping. Best iteration:
# [3796]	train-rmse:1.07042	eval-rmse:1.16307
#
# [0]	train-rmse:1.71182	eval-rmse:1.61821
# Multiple eval metrics have been passed: 'eval-rmse' will be used for early stopping.
#
# Will train until eval-rmse hasn't improved in 100 rounds.
# [100]	train-rmse:1.44685	eval-rmse:1.34621
# [200]	train-rmse:1.31998	eval-rmse:1.21924
# [300]	train-rmse:1.25692	eval-rmse:1.15906
# [400]	train-rmse:1.22365	eval-rmse:1.131
# [500]	train-rmse:1.20362	eval-rmse:1.11666
# [600]	train-rmse:1.19021	eval-rmse:1.10875
# [700]	train-rmse:1.18077	eval-rmse:1.10429
# [800]	train-rmse:1.17332	eval-rmse:1.10139
# [900]	train-rmse:1.16733	eval-rmse:1.09941
# [1000]	train-rmse:1.16205	eval-rmse:1.09791
# [1100]	train-rmse:1.15741	eval-rmse:1.09655
# [1200]	train-rmse:1.15304	eval-rmse:1.09572
# [1300]	train-rmse:1.14897	eval-rmse:1.09496
# [1400]	train-rmse:1.14525	eval-rmse:1.09435
# [1500]	train-rmse:1.14159	eval-rmse:1.09393
# [1600]	train-rmse:1.13811	eval-rmse:1.09359
# [1700]	train-rmse:1.13482	eval-rmse:1.09324
# [1800]	train-rmse:1.13145	eval-rmse:1.093
# [1900]	train-rmse:1.12849	eval-rmse:1.09262
# [2000]	train-rmse:1.12578	eval-rmse:1.09239
# [2100]	train-rmse:1.1233	eval-rmse:1.09224
# [2200]	train-rmse:1.12098	eval-rmse:1.09203
# [2300]	train-rmse:1.11862	eval-rmse:1.09181
# [2400]	train-rmse:1.1163	eval-rmse:1.09177
# [2500]	train-rmse:1.11389	eval-rmse:1.09158
# [2600]	train-rmse:1.1115	eval-rmse:1.09145
# [2700]	train-rmse:1.10906	eval-rmse:1.09142
# [2800]	train-rmse:1.10665	eval-rmse:1.09142
# [2900]	train-rmse:1.10465	eval-rmse:1.09134
# [3000]	train-rmse:1.10269	eval-rmse:1.09124
# [3100]	train-rmse:1.10056	eval-rmse:1.09115
# [3200]	train-rmse:1.09842	eval-rmse:1.09118
# Stopping. Best iteration:
# [3116]	train-rmse:1.10026	eval-rmse:1.09111
#
# [0]	train-rmse:1.66013	eval-rmse:1.77261
# Multiple eval metrics have been passed: 'eval-rmse' will be used for early stopping.
#
# Will train until eval-rmse hasn't improved in 100 rounds.
# [100]	train-rmse:1.39973	eval-rmse:1.50593
# [200]	train-rmse:1.27587	eval-rmse:1.37853
# [300]	train-rmse:1.21411	eval-rmse:1.31587
# [400]	train-rmse:1.18122	eval-rmse:1.28514
# [500]	train-rmse:1.16125	eval-rmse:1.2685
# [600]	train-rmse:1.14823	eval-rmse:1.25903
# [700]	train-rmse:1.13879	eval-rmse:1.25335
# [800]	train-rmse:1.13194	eval-rmse:1.24955
# [900]	train-rmse:1.1261	eval-rmse:1.24687
# [1000]	train-rmse:1.121	eval-rmse:1.24494
# [1100]	train-rmse:1.11671	eval-rmse:1.24331
# [1200]	train-rmse:1.11268	eval-rmse:1.24218
# [1300]	train-rmse:1.1086	eval-rmse:1.24125
# [1400]	train-rmse:1.10516	eval-rmse:1.24058
# [1500]	train-rmse:1.10191	eval-rmse:1.23993
# [1600]	train-rmse:1.09872	eval-rmse:1.23941
# [1700]	train-rmse:1.09588	eval-rmse:1.23898
# [1800]	train-rmse:1.09287	eval-rmse:1.23873
# [1900]	train-rmse:1.09045	eval-rmse:1.23842
# [2000]	train-rmse:1.08809	eval-rmse:1.23823
# [2100]	train-rmse:1.08584	eval-rmse:1.23804
# [2200]	train-rmse:1.08358	eval-rmse:1.23781
# [2300]	train-rmse:1.08136	eval-rmse:1.23762
# [2400]	train-rmse:1.07936	eval-rmse:1.23745
# [2500]	train-rmse:1.07742	eval-rmse:1.23732
# [2600]	train-rmse:1.0753	eval-rmse:1.23716
# [2700]	train-rmse:1.07322	eval-rmse:1.237
# [2800]	train-rmse:1.07119	eval-rmse:1.23691
# [2900]	train-rmse:1.06919	eval-rmse:1.23681
# [3000]	train-rmse:1.06738	eval-rmse:1.23674
# [3100]	train-rmse:1.06565	eval-rmse:1.23661
# [3200]	train-rmse:1.06373	eval-rmse:1.2365
# [3300]	train-rmse:1.06181	eval-rmse:1.23641
# [3400]	train-rmse:1.06004	eval-rmse:1.23635
# [3500]	train-rmse:1.05841	eval-rmse:1.23632
# [3600]	train-rmse:1.0565	eval-rmse:1.23622
# [3700]	train-rmse:1.05448	eval-rmse:1.23618
# Stopping. Best iteration:
# [3680]	train-rmse:1.05488	eval-rmse:1.23616
#
# 1.221340309035831 1.1630921420729596 1.0911869165296026 1.2362106029587967
# 1.1779574926492975

# %%
#学習結果のプロット
# %matplotlib inline
def plot_loss(evals_result, title):
    train_metric = evals_result['train']['rmse']
    plt.plot(train_metric, label='train rmse')
    eval_metric = evals_result['eval']['rmse']
    plt.plot(eval_metric, label='eval rmse')
    plt.grid()
    plt.legend()
    plt.title(title)
    plt.xlabel('rounds')
    plt.ylabel('rmse')
    plt.show()

# %%
for i in range(4):
    plot_loss(histories[i],f'Training Dataset: {i}')

# %%
test_length = len(test_data)
predict = np.array([0.0]*test_length)
dtest = xgb.DMatrix(test_x,label=test_y) #本来は学習に使用していないデータにする
for i in range(4):
    y_pred_proba = models[i].predict(dtest)
    predict += y_pred_proba

predict /= 4

# %%
y = pd.DataFrame(predict,columns=["y'"])
output = test_data #ここも書き換えること

output = pd.concat([output,y],axis=1)

output["複勝配当"] = output["複勝配当"].astype("int64")
output.to_csv("C:/programs/HRP/neweval2.csv",index=False,encoding="shift-jis")

# %%
fscore = model.get_score(importance_type="total_gain")
fscore = sorted([(k,v) for k,v in fscore.items()] ,key=lambda tpl: tpl[1], reverse = True)
print(*fscore[:20])
# Out:
# ('単勝オッズ', 3492572.4635870676) ('距離', 1694243.5416334886) ('前走着差タイム', 1140153.4787201136) ('芝・ダ', 664996.569027006) ('前好走', 609788.0070962401) ('キャリア', 551218.0292882508) ('前距離', 439763.2277402356) ('前走単勝オッズ', 434137.159053452) ('斤量', 386511.5937705645) ('前走平均1Fタイム', 377983.1644713986) ('前走上り3F', 275277.3263236548) ('前走Ave-3F', 243522.8684330268) ('間隔', 201532.0036096291) ('前PCI', 199980.5888149277) ('クラス名', 179839.81269066693) ('前走PCI3', 160951.28051479248) ('前芝・ダ', 144527.81902468624) ('前走RPCI', 114964.21733454401) ('騎手コード', 103472.45967804591) ('前走騎手コード', 102568.98265458697)
