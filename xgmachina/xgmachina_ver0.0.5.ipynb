# %% [markdown]
# 順位を指標に回帰させる。

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import KFold
from sklearn.metrics import mean_squared_error
import xgboost as xgb
from matplotlib import pyplot as plt
import warnings
warnings.simplefilter('ignore')

# %%
data_dir = "F:/TARGET frontier/TXT33/"
data_name = "train"
tail = "fe6"
train_data = pd.read_csv(data_dir+data_name+tail+".csv",encoding="shift-jis",dtype={'レースID(旧)':str})

# %%
pd.set_option('display.max_columns', 100)
train_data.head()
# Out:
#    場所  芝・ダ    距離  クラス名  馬場状態  騎手コード  枠番  性別  年齢  キャリア    斤量   間隔  休み明け〜戦目  \
# 0   2    2  1200     2     3   5212   6   2   3    13  56.0  6.0      5.0
# 1   2    2  1200     2     3   5339   6   1   3    10  54.0  3.0      3.0
# 2   2    2  1200     2     3   5203   3   2   3     9  56.0  5.0      2.0
# 3   2    2  1200     2     3   1150   4   1   5    17  55.0  2.0      4.0
# 4   2    2  1200     2     3   1004   8   1   3    15  54.0  2.0      4.0
#
#    種牡馬  父タイプ名  調教師コード  前走場所  前芝・ダ     前距離  前クラス名  前走馬場状態  前走騎手コード  前走枠番  前走脚質  \
# 0  572      8    1105    13     2  1400.0      2       2    660.0   2.0     3
# 1  452      8    1002     1     2  1200.0      7       3   5339.0   7.0     3
# 2  607      5    1089     3     2  1200.0      2       3   1018.0   8.0     2
# 3   91      1    1134     2     2  1200.0      2       2   1150.0   6.0     2
# 4  325      4    1030     2     2  1200.0      2       2   1134.0   2.0     5
#
#    前走斤量  前走Ave-3F  前走上り3F  前走PCI3  前走RPCI  前PCI  前好走  前走平均1Fタイム  前走着差タイム  \
# 0  54.0      37.2    33.9   59.53    58.2  59.7    0      11.93      0.2
# 1  54.0      34.5    34.6   48.80    46.9  49.7    0      11.52      0.0
# 2  56.0      34.5    34.4   50.13    48.0  50.3    0      11.48      0.4
# 3  53.0      34.1    34.4   48.17    46.3  49.1    0      11.42      0.0
# 4  53.0      33.6    36.4   48.17    46.3  42.3    1      11.67      1.5
#
#    前走単勝オッズ   着差    レースID(旧)  複勝オッズ下限  複勝オッズ上限   複勝配当  単勝オッズ  順位  頭数
# 0     14.6  0.0  0615581112      1.9      2.7  190.0    5.4   1  16
# 1      2.2  0.0  0615581111      1.3      1.6  130.0    2.8   2  16
# 2     28.6  0.2  0615581106      1.8      2.5  180.0    6.2   3  16
# 3     19.1  0.3  0615581108      1.7      2.5    0.0    6.6   4  16
# 4      8.6  0.3  0615581116      6.3      9.7    0.0   33.9   5  16

# %%
#test_data
test_data = pd.read_csv(data_dir+"predict"+tail+".csv",encoding="shift-jis",dtype={'レースID(旧)':str})
test_x = test_data.drop(["着差","レースID(旧)","複勝オッズ下限","複勝オッズ上限","複勝配当","順位","単勝オッズ"],axis=1)
test_y = test_data["順位"]

# %%
train_x = train_data.drop(["着差","レースID(旧)","複勝オッズ下限","複勝オッズ上限","複勝配当","順位","単勝オッズ"],axis=1)
train_y = train_data["順位"]

# %%
#チューニング済みパラメータ(etaのみ手動)
params = {'colsample_bytree': 0.65, 
          'gamma': 0.013439667332810353, 
          'max_depth': 5, 
          'min_child_weight': 2.663317188920419, 
          'subsample': 0.9, 
          'booster': 'gbtree', 
          'objective': 'reg:squarederror', 
          'eta': 0.01, 
          'alpha': 0.0, 
          'lambda': 1.0, 
          'random_state': 71}

# %%
#これがないとエラー履くので注意
train_y.fillna(10,inplace=True) #無ければ10位に
test_y.fillna(10,inplace=True)

# %%
scores = []
histories = []
models = []
kf = KFold(n_splits=4,shuffle=False)
for tr_idx,va_idx in kf.split(train_x):
    tr_x, va_x = train_x.iloc[tr_idx], train_x.iloc[va_idx]
    tr_y, va_y = train_y.iloc[tr_idx], train_y.iloc[va_idx]
    dtrain = xgb.DMatrix(tr_x,label=tr_y)
    dvalid = xgb.DMatrix(va_x,label=va_y)
    watchlist = [(dtrain,"train"),(dvalid,"eval")]
    evals_result = {}
    model = xgb.train(
        params,
        dtrain,
        num_boost_round=10000,
        early_stopping_rounds=100,
        evals=watchlist,
        evals_result=evals_result,
        verbose_eval=500
    )
    models.append(model)
    histories.append(evals_result)
    va_pred = model.predict(dvalid)
    va_y.fillna(0.5,inplace=True) #ここまでok
    #print(va_pred[:10])
    #print(va_y[:10])
    score = mean_squared_error(va_y,va_pred)
    score = np.sqrt(mean_squared_error(va_y,va_pred)) #rmse
    scores.append(score)

print(*scores)
print(np.mean(scores))
# Out:
# [0]	train-rmse:8.54614	eval-rmse:8.62123
# Multiple eval metrics have been passed: 'eval-rmse' will be used for early stopping.
#
# Will train until eval-rmse hasn't improved in 100 rounds.
# [100]	train-rmse:4.78527	eval-rmse:4.87947
# [200]	train-rmse:3.95538	eval-rmse:4.03849
# [300]	train-rmse:3.79191	eval-rmse:3.86613
# [400]	train-rmse:3.74392	eval-rmse:3.81672
# [500]	train-rmse:3.71794	eval-rmse:3.79353
# [600]	train-rmse:3.69863	eval-rmse:3.7783
# [700]	train-rmse:3.68311	eval-rmse:3.76761
# [800]	train-rmse:3.66853	eval-rmse:3.75804
# [900]	train-rmse:3.65653	eval-rmse:3.75077
# [1000]	train-rmse:3.64533	eval-rmse:3.74468
# [1100]	train-rmse:3.63554	eval-rmse:3.73961
# [1200]	train-rmse:3.62623	eval-rmse:3.73522
# [1300]	train-rmse:3.61797	eval-rmse:3.73166
# [1400]	train-rmse:3.61032	eval-rmse:3.72871
# [1500]	train-rmse:3.60302	eval-rmse:3.72635
# [1600]	train-rmse:3.59587	eval-rmse:3.72403
# [1700]	train-rmse:3.58924	eval-rmse:3.72207
# [1800]	train-rmse:3.58278	eval-rmse:3.72016
# [1900]	train-rmse:3.57686	eval-rmse:3.71851
# [2000]	train-rmse:3.57072	eval-rmse:3.71686
# [2100]	train-rmse:3.56521	eval-rmse:3.71567
# [2200]	train-rmse:3.55968	eval-rmse:3.71442
# [2300]	train-rmse:3.55403	eval-rmse:3.71324
# [2400]	train-rmse:3.54886	eval-rmse:3.71239
# [2500]	train-rmse:3.54372	eval-rmse:3.71151
# [2600]	train-rmse:3.53837	eval-rmse:3.71062
# [2700]	train-rmse:3.53363	eval-rmse:3.70985
# [2800]	train-rmse:3.52874	eval-rmse:3.70934
# [2900]	train-rmse:3.52379	eval-rmse:3.70871
# [3000]	train-rmse:3.5191	eval-rmse:3.70805
# [3100]	train-rmse:3.51451	eval-rmse:3.70751
# [3200]	train-rmse:3.51006	eval-rmse:3.7071
# [3300]	train-rmse:3.50548	eval-rmse:3.70652
# [3400]	train-rmse:3.50113	eval-rmse:3.70614
# [3500]	train-rmse:3.4969	eval-rmse:3.70564
# [3600]	train-rmse:3.49249	eval-rmse:3.70511
# [3700]	train-rmse:3.48809	eval-rmse:3.70478
# [3800]	train-rmse:3.48389	eval-rmse:3.70432
# [3900]	train-rmse:3.47964	eval-rmse:3.704
# [4000]	train-rmse:3.47537	eval-rmse:3.70366
# [4100]	train-rmse:3.47107	eval-rmse:3.70347
# [4200]	train-rmse:3.46704	eval-rmse:3.70329
# [4300]	train-rmse:3.46296	eval-rmse:3.70288
# [4400]	train-rmse:3.45892	eval-rmse:3.70262
# [4500]	train-rmse:3.45474	eval-rmse:3.70229
# [4600]	train-rmse:3.45058	eval-rmse:3.70199
# [4700]	train-rmse:3.44661	eval-rmse:3.70189
# [4800]	train-rmse:3.44246	eval-rmse:3.70164
# [4900]	train-rmse:3.43852	eval-rmse:3.70142
# [5000]	train-rmse:3.43436	eval-rmse:3.70119
# [5100]	train-rmse:3.43036	eval-rmse:3.701
# [5200]	train-rmse:3.4266	eval-rmse:3.7009
# [5300]	train-rmse:3.42258	eval-rmse:3.70055
# [5400]	train-rmse:3.41873	eval-rmse:3.70038
# [5500]	train-rmse:3.41521	eval-rmse:3.70026
# [5600]	train-rmse:3.41155	eval-rmse:3.70012
# [5700]	train-rmse:3.40775	eval-rmse:3.69995
# [5800]	train-rmse:3.40416	eval-rmse:3.69991
# [5900]	train-rmse:3.40041	eval-rmse:3.69983
# [6000]	train-rmse:3.39673	eval-rmse:3.69965
# [6100]	train-rmse:3.393	eval-rmse:3.69964
# [6200]	train-rmse:3.38926	eval-rmse:3.69971
# Stopping. Best iteration:
# [6148]	train-rmse:3.39111	eval-rmse:3.6996
#
# [0]	train-rmse:8.54341	eval-rmse:8.62838
# Multiple eval metrics have been passed: 'eval-rmse' will be used for early stopping.
#
# Will train until eval-rmse hasn't improved in 100 rounds.
# [100]	train-rmse:4.78262	eval-rmse:4.85296
# [200]	train-rmse:3.95234	eval-rmse:4.02183
# [300]	train-rmse:3.78912	eval-rmse:3.86105
# [400]	train-rmse:3.74126	eval-rmse:3.81817
# [500]	train-rmse:3.71576	eval-rmse:3.79859
# [600]	train-rmse:3.69606	eval-rmse:3.78415
# [700]	train-rmse:3.6806	eval-rmse:3.77364
# [800]	train-rmse:3.66721	eval-rmse:3.76518
# [900]	train-rmse:3.65506	eval-rmse:3.75764
# [1000]	train-rmse:3.64413	eval-rmse:3.75131
# [1100]	train-rmse:3.63437	eval-rmse:3.74601
# [1200]	train-rmse:3.62527	eval-rmse:3.74143
# [1300]	train-rmse:3.61706	eval-rmse:3.73757
# [1400]	train-rmse:3.60911	eval-rmse:3.73392
# [1500]	train-rmse:3.60198	eval-rmse:3.73079
# [1600]	train-rmse:3.59489	eval-rmse:3.72788
# [1700]	train-rmse:3.58819	eval-rmse:3.72537
# [1800]	train-rmse:3.58184	eval-rmse:3.72301
# [1900]	train-rmse:3.57584	eval-rmse:3.72116
# [2000]	train-rmse:3.56979	eval-rmse:3.71919
# [2100]	train-rmse:3.56408	eval-rmse:3.71752
# [2200]	train-rmse:3.55857	eval-rmse:3.71597
# [2300]	train-rmse:3.55323	eval-rmse:3.71468
# [2400]	train-rmse:3.54786	eval-rmse:3.71335
# [2500]	train-rmse:3.54256	eval-rmse:3.712
# [2600]	train-rmse:3.53735	eval-rmse:3.71072
# [2700]	train-rmse:3.53246	eval-rmse:3.70976
# [2800]	train-rmse:3.52746	eval-rmse:3.70862
# [2900]	train-rmse:3.52257	eval-rmse:3.70785
# [3000]	train-rmse:3.51784	eval-rmse:3.70696
# [3100]	train-rmse:3.51322	eval-rmse:3.70638
# [3200]	train-rmse:3.50855	eval-rmse:3.70564
# [3300]	train-rmse:3.50417	eval-rmse:3.70503
# [3400]	train-rmse:3.49953	eval-rmse:3.70423
# [3500]	train-rmse:3.49537	eval-rmse:3.70369
# [3600]	train-rmse:3.49077	eval-rmse:3.70304
# [3700]	train-rmse:3.48607	eval-rmse:3.7025
# [3800]	train-rmse:3.48198	eval-rmse:3.70193
# [3900]	train-rmse:3.47747	eval-rmse:3.70139
# [4000]	train-rmse:3.47319	eval-rmse:3.70103
# [4100]	train-rmse:3.46879	eval-rmse:3.70052
# [4200]	train-rmse:3.46458	eval-rmse:3.70007
# [4300]	train-rmse:3.46043	eval-rmse:3.69982
# [4400]	train-rmse:3.45645	eval-rmse:3.69943
# [4500]	train-rmse:3.45253	eval-rmse:3.69911
# [4600]	train-rmse:3.44851	eval-rmse:3.69876
# [4700]	train-rmse:3.44427	eval-rmse:3.6984
# [4800]	train-rmse:3.44014	eval-rmse:3.69789
# [4900]	train-rmse:3.43604	eval-rmse:3.6975
# [5000]	train-rmse:3.43207	eval-rmse:3.69703
# [5100]	train-rmse:3.42811	eval-rmse:3.69672
# [5200]	train-rmse:3.42423	eval-rmse:3.69651
# [5300]	train-rmse:3.42046	eval-rmse:3.69612
# [5400]	train-rmse:3.41637	eval-rmse:3.69587
# [5500]	train-rmse:3.41251	eval-rmse:3.69549
# [5600]	train-rmse:3.40861	eval-rmse:3.69517
# [5700]	train-rmse:3.40493	eval-rmse:3.69498
# [5800]	train-rmse:3.40122	eval-rmse:3.69485
# [5900]	train-rmse:3.39743	eval-rmse:3.6946
# [6000]	train-rmse:3.39368	eval-rmse:3.69446
# [6100]	train-rmse:3.39017	eval-rmse:3.69424
# [6200]	train-rmse:3.38649	eval-rmse:3.69414
# [6300]	train-rmse:3.38278	eval-rmse:3.69394
# [6400]	train-rmse:3.37901	eval-rmse:3.6938
# [6500]	train-rmse:3.37528	eval-rmse:3.69373
# [6600]	train-rmse:3.37174	eval-rmse:3.69363
# [6700]	train-rmse:3.36789	eval-rmse:3.69348
# [6800]	train-rmse:3.3643	eval-rmse:3.69339
# [6900]	train-rmse:3.36065	eval-rmse:3.69326
# [7000]	train-rmse:3.35705	eval-rmse:3.69327
# [7100]	train-rmse:3.35327	eval-rmse:3.69317
# [7200]	train-rmse:3.34982	eval-rmse:3.69307
# [7300]	train-rmse:3.34624	eval-rmse:3.69305
# [7400]	train-rmse:3.3426	eval-rmse:3.69291
# [7500]	train-rmse:3.33899	eval-rmse:3.69286
# [7600]	train-rmse:3.33547	eval-rmse:3.69278
# [7700]	train-rmse:3.3319	eval-rmse:3.69256
# [7800]	train-rmse:3.32837	eval-rmse:3.69249
# [7900]	train-rmse:3.32483	eval-rmse:3.6924
# [8000]	train-rmse:3.32136	eval-rmse:3.69229
# [8100]	train-rmse:3.31793	eval-rmse:3.69226
# [8200]	train-rmse:3.31444	eval-rmse:3.69227
# Stopping. Best iteration:
# [8116]	train-rmse:3.31738	eval-rmse:3.69223
#
# [0]	train-rmse:8.56892	eval-rmse:8.55224
# Multiple eval metrics have been passed: 'eval-rmse' will be used for early stopping.
#
# Will train until eval-rmse hasn't improved in 100 rounds.
# [100]	train-rmse:4.80042	eval-rmse:4.7925
# [200]	train-rmse:3.96894	eval-rmse:3.96908
# [300]	train-rmse:3.80549	eval-rmse:3.8111
# [400]	train-rmse:3.75789	eval-rmse:3.76813
# [500]	train-rmse:3.73228	eval-rmse:3.74747
# [600]	train-rmse:3.71307	eval-rmse:3.73305
# [700]	train-rmse:3.69673	eval-rmse:3.72199
# [800]	train-rmse:3.68263	eval-rmse:3.71297
# [900]	train-rmse:3.67043	eval-rmse:3.70587
# [1000]	train-rmse:3.65918	eval-rmse:3.6997
# [1100]	train-rmse:3.64961	eval-rmse:3.69471
# [1200]	train-rmse:3.64084	eval-rmse:3.69063
# [1300]	train-rmse:3.63253	eval-rmse:3.68703
# [1400]	train-rmse:3.62472	eval-rmse:3.68368
# [1500]	train-rmse:3.61729	eval-rmse:3.68088
# [1600]	train-rmse:3.61025	eval-rmse:3.67835
# [1700]	train-rmse:3.60379	eval-rmse:3.67636
# [1800]	train-rmse:3.59716	eval-rmse:3.67425
# [1900]	train-rmse:3.59104	eval-rmse:3.67249
# [2000]	train-rmse:3.585	eval-rmse:3.67069
# [2100]	train-rmse:3.57931	eval-rmse:3.66927
# [2200]	train-rmse:3.57359	eval-rmse:3.6678
# [2300]	train-rmse:3.56799	eval-rmse:3.66655
# [2400]	train-rmse:3.56266	eval-rmse:3.66538
# [2500]	train-rmse:3.55739	eval-rmse:3.66423
# [2600]	train-rmse:3.5521	eval-rmse:3.66331
# [2700]	train-rmse:3.54717	eval-rmse:3.6625
# [2800]	train-rmse:3.54198	eval-rmse:3.66161
# [2900]	train-rmse:3.53716	eval-rmse:3.6609
# [3000]	train-rmse:3.53238	eval-rmse:3.66004
# [3100]	train-rmse:3.52768	eval-rmse:3.65925
# [3200]	train-rmse:3.52305	eval-rmse:3.65858
# [3300]	train-rmse:3.51855	eval-rmse:3.65805
# [3400]	train-rmse:3.51382	eval-rmse:3.65741
# [3500]	train-rmse:3.50945	eval-rmse:3.65681
# [3600]	train-rmse:3.50511	eval-rmse:3.65636
# [3700]	train-rmse:3.50056	eval-rmse:3.65579
# [3800]	train-rmse:3.49608	eval-rmse:3.65532
# [3900]	train-rmse:3.4917	eval-rmse:3.65476
# [4000]	train-rmse:3.48742	eval-rmse:3.65429
# [4100]	train-rmse:3.48305	eval-rmse:3.65389
# [4200]	train-rmse:3.47874	eval-rmse:3.65347
# [4300]	train-rmse:3.47458	eval-rmse:3.65312
# [4400]	train-rmse:3.47032	eval-rmse:3.65264
# [4500]	train-rmse:3.46616	eval-rmse:3.6523
# [4600]	train-rmse:3.46224	eval-rmse:3.65197
# [4700]	train-rmse:3.45794	eval-rmse:3.65159
# [4800]	train-rmse:3.45397	eval-rmse:3.65125
# [4900]	train-rmse:3.44988	eval-rmse:3.65096
# [5000]	train-rmse:3.44578	eval-rmse:3.6506
# [5100]	train-rmse:3.44189	eval-rmse:3.65039
# [5200]	train-rmse:3.43812	eval-rmse:3.65019
# [5300]	train-rmse:3.43429	eval-rmse:3.64995
# [5400]	train-rmse:3.43045	eval-rmse:3.64966
# [5500]	train-rmse:3.42671	eval-rmse:3.64941
# [5600]	train-rmse:3.42297	eval-rmse:3.64921
# [5700]	train-rmse:3.41911	eval-rmse:3.64901
# [5800]	train-rmse:3.41539	eval-rmse:3.64886
# [5900]	train-rmse:3.41161	eval-rmse:3.6487
# [6000]	train-rmse:3.40772	eval-rmse:3.64842
# [6100]	train-rmse:3.40393	eval-rmse:3.64827
# [6200]	train-rmse:3.40028	eval-rmse:3.64818
# [6300]	train-rmse:3.3967	eval-rmse:3.64807
# [6400]	train-rmse:3.39293	eval-rmse:3.64798
# [6500]	train-rmse:3.38941	eval-rmse:3.6479
# [6600]	train-rmse:3.38583	eval-rmse:3.64779
# [6700]	train-rmse:3.38225	eval-rmse:3.64766
# [6800]	train-rmse:3.37854	eval-rmse:3.64757
# [6900]	train-rmse:3.37515	eval-rmse:3.64758
# Stopping. Best iteration:
# [6801]	train-rmse:3.3785	eval-rmse:3.64757
#
# [0]	train-rmse:8.60035	eval-rmse:8.45611
# Multiple eval metrics have been passed: 'eval-rmse' will be used for early stopping.
#
# Will train until eval-rmse hasn't improved in 100 rounds.
# [100]	train-rmse:4.82036	eval-rmse:4.68748
# [200]	train-rmse:3.98644	eval-rmse:3.88449
# [300]	train-rmse:3.82253	eval-rmse:3.74301
# [400]	train-rmse:3.77497	eval-rmse:3.70829
# [500]	train-rmse:3.74963	eval-rmse:3.6914
# [600]	train-rmse:3.73023	eval-rmse:3.6785
# [700]	train-rmse:3.71362	eval-rmse:3.66766
# [800]	train-rmse:3.69941	eval-rmse:3.65907
# [900]	train-rmse:3.68698	eval-rmse:3.65185
# [1000]	train-rmse:3.67546	eval-rmse:3.64563
# [1100]	train-rmse:3.66543	eval-rmse:3.64065
# [1200]	train-rmse:3.65646	eval-rmse:3.63663
# [1300]	train-rmse:3.64805	eval-rmse:3.63304
# [1400]	train-rmse:3.64013	eval-rmse:3.62981
# [1500]	train-rmse:3.63296	eval-rmse:3.62731
# [1600]	train-rmse:3.62566	eval-rmse:3.62492
# [1700]	train-rmse:3.61925	eval-rmse:3.62306
# [1800]	train-rmse:3.61278	eval-rmse:3.62126
# [1900]	train-rmse:3.60646	eval-rmse:3.61963
# [2000]	train-rmse:3.60059	eval-rmse:3.61831
# [2100]	train-rmse:3.59452	eval-rmse:3.61699
# [2200]	train-rmse:3.58867	eval-rmse:3.61575
# [2300]	train-rmse:3.58302	eval-rmse:3.61457
# [2400]	train-rmse:3.57748	eval-rmse:3.61358
# [2500]	train-rmse:3.57205	eval-rmse:3.61264
# [2600]	train-rmse:3.56702	eval-rmse:3.61188
# [2700]	train-rmse:3.56212	eval-rmse:3.61118
# [2800]	train-rmse:3.55711	eval-rmse:3.61032
# [2900]	train-rmse:3.55224	eval-rmse:3.60967
# [3000]	train-rmse:3.54752	eval-rmse:3.60899
# [3100]	train-rmse:3.54243	eval-rmse:3.60821
# [3200]	train-rmse:3.53755	eval-rmse:3.60756
# [3300]	train-rmse:3.53317	eval-rmse:3.60711
# [3400]	train-rmse:3.52858	eval-rmse:3.60649
# [3500]	train-rmse:3.52416	eval-rmse:3.60607
# [3600]	train-rmse:3.51985	eval-rmse:3.6057
# [3700]	train-rmse:3.51523	eval-rmse:3.60526
# [3800]	train-rmse:3.51089	eval-rmse:3.60488
# [3900]	train-rmse:3.50674	eval-rmse:3.6045
# [4000]	train-rmse:3.50223	eval-rmse:3.60424
# [4100]	train-rmse:3.49812	eval-rmse:3.60408
# [4200]	train-rmse:3.49388	eval-rmse:3.60371
# [4300]	train-rmse:3.48975	eval-rmse:3.6036
# Stopping. Best iteration:
# [4256]	train-rmse:3.49152	eval-rmse:3.60355
#
# 3.6996967325758443 3.692246631744885 3.6475885669419874 3.603599279297348
# 3.660782802640016

# %%
#学習結果のプロット
# %matplotlib inline
def plot_loss(evals_result, title):
    train_metric = evals_result['train']['rmse']
    plt.plot(train_metric, label='train rmse')
    eval_metric = evals_result['eval']['rmse']
    plt.plot(eval_metric, label='eval rmse')
    plt.grid()
    plt.legend()
    plt.title(title)
    plt.xlabel('rounds')
    plt.ylabel('rmse')
    plt.show()

# %%
for i in range(4):
    plot_loss(histories[i],f'Training Dataset: {i}')

# %%
test_length = len(test_data)
predict = np.array([0.0]*test_length)
dtest = xgb.DMatrix(test_x,label=test_y) #本来は学習に使用していないデータにする
for i in range(4):
    y_pred_proba = models[i].predict(dtest)
    predict += y_pred_proba

predict /= 4

# %%
y = pd.DataFrame(predict,columns=["y'"])
output = test_data #ここも書き換えること

output = pd.concat([output,y],axis=1)

output["複勝配当"] = output["複勝配当"].astype("int64")
output.to_csv("C:/programs/HRP/neweval3.csv",index=False,encoding="shift-jis")

# %%
fscore = model.get_score(importance_type="total_gain")
fscore = sorted([(k,v) for k,v in fscore.items()] ,key=lambda tpl: tpl[1], reverse = True)
print(*fscore[:20])
# Out:
# ('前走単勝オッズ', 14125402.05544214) ('頭数', 7255929.220887611) ('前走着差タイム', 4629262.381352766) ('前好走', 4173208.6088161417) ('クラス名', 1626876.6636483101) ('前クラス名', 1437219.994885352) ('間隔', 1410869.046037393) ('前距離', 1369902.7787345902) ('騎手コード', 1356857.753717283) ('距離', 965231.0411329799) ('前走上り3F', 959533.2428201815) ('前走平均1Fタイム', 817616.0903490396) ('キャリア', 782203.9354215554) ('前走PCI3', 762735.9708860663) ('前PCI', 669457.7652076227) ('前走Ave-3F', 654232.7731898377) ('調教師コード', 597173.6252584674) ('種牡馬', 596147.7818678366) ('前走RPCI', 523810.16500754363) ('芝・ダ', 522892.1658827501)

# %%
#全体を100[%]とした時の重要度
mother = sum([j for i,j in fscore])
for i,j in fscore[:25]:
    print(i,round((j/mother)*100,1))
# Out:
# 前走単勝オッズ 28.5
# 頭数 14.7
# 前走着差タイム 9.3
# 前好走 8.4
# クラス名 3.3
# 前クラス名 2.9
# 間隔 2.8
# 前距離 2.8
# 騎手コード 2.7
# 距離 1.9
# 前走上り3F 1.9
# 前走平均1Fタイム 1.7
# キャリア 1.6
# 前走PCI3 1.5
# 前PCI 1.4
# 前走Ave-3F 1.3
# 調教師コード 1.2
# 種牡馬 1.2
# 前走RPCI 1.1
# 芝・ダ 1.1
# 前走騎手コード 1.0
# 前走脚質 0.9
# 休み明け〜戦目 0.8
# 前走場所 0.8
# 斤量 0.7

# %%
slen = 20
label = []
weight = []
for i,j in fscore[:slen]:
    label.append(i)
    weight.append(j)

plt.rcdefaults() #横棒グラフモード
fig, ax = plt.subplots()
y_pos = np.arange(slen)
ax.barh(y_pos, weight,align='center')
ax.set_yticks(y_pos)
ax.set_yticklabels(label)
ax.invert_yaxis()
ax.set_xlabel('label')
ax.set_title('xgboost特徴量')
plt.show()
